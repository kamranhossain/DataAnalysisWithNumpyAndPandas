# %%
word = open('words','r')

# %%
word
# Out:
# <_io.TextIOWrapper name='words' mode='r' encoding='UTF-8'>

# %%
wordlist = word.readlines()

# %%
wordlist[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
len(wordlist)
# Out:
# 235886

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron'.lower()
# Out:
# 'aaron'

# %%
wordclean = [word.strip().lower() for word in wordlist]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordunique = list(set(wordclean))

# %%
wordunique
# Out:
# ['ovoviviparous',
#  'manscape',
#  'trunched',
#  'opobalsam',
#  'gaumish',
#  'megalichthyidae',
#  'agaricin',
#  'blithelike',
#  'dodgeful',
#  'shawanese',
#  'frambesia',
#  'sensualist',
#  'unbiting',
#  'reactionally',
#  'buddage',
#  'suboverseer',
#  'faceplate',
#  'stiller',
#  'xyloid',
#  'cletch',
#  'calliandra',
#  'intoxicator',
#  'muilla',
#  'hocket',
#  'hildebrand',
#  'jova',
#  'nasobasilar',
#  'octavarium',
#  'periosteal',
#  'angeldom',
#  'odontophore',
#  'simoniac',
#  'diopter',
#  'skeletogenous',
#  'seedsman',
#  'ulotrichi',
#  'hogget',
#  'spaniel',
#  'dialdehyde',
#  'vester',
#  'eurycerotidae',
#  'tuskless',
#  'didactical',
#  'echelette',
#  'trachycarpus',
#  'apothesine',
#  'myrothamnaceae',
#  'embracingly',
#  'nationalism',
#  'corollitic',
#  'broguery',
#  'thermogalvanometer',
#  'filterableness',
#  'inomyositis',
#  'aconitum',
#  'cumbrance',
#  'passionful',
#  'banate',
#  'stephanotis',
#  'infraglenoid',
#  'eudist',
#  'glaciarium',
#  'omental',
#  'virilify',
#  'leucotoxic',
#  'grebo',
#  'ostealgia',
#  'paleola',
#  'combinator',
#  'pledge',
#  'cupeler',
#  'londres',
#  'illogicality',
#  'perquisitor',
#  'predrawer',
#  'subconchoidal',
#  'sweeper',
#  'tolu',
#  'sketchy',
#  'matlockite',
#  'traceless',
#  'awaft',
#  'gainset',
#  'farde',
#  'salvational',
#  'guardable',
#  'petaline',
#  'gulancha',
#  'soldiering',
#  'medicate',
#  'trichostrongylid',
#  'matezite',
#  'sobbing',
#  'coregence',
#  'phoniatry',
#  'cheesecake',
#  'overwound',
#  'radiometric',
#  'elytrocele',
#  'origenize',
#  'semisaturation',
#  'dromic',
#  'lockage',
#  'molossidae',
#  'persianization',
#  'anthracin',
#  'wheen',
#  'hogherd',
#  'bambusa',
#  'deanimalize',
#  'anthropolitic',
#  'pharmic',
#  'tantalofluoride',
#  'synaptychus',
#  'unanatomizable',
#  'chinik',
#  'extrasacerdotal',
#  'gleanable',
#  'nonrecollection',
#  'plantad',
#  'established',
#  'subpoena',
#  'soapmonger',
#  'jambstone',
#  'plated',
#  'unenquired',
#  'alpian',
#  'archegosaurus',
#  'overgrow',
#  'sider',
#  'epicoracoidal',
#  'dictyonina',
#  'unslung',
#  'idiocrasis',
#  'mehtar',
#  'kerry',
#  'cricothyreoid',
#  'heterotricha',
#  'cany',
#  'tritylodon',
#  'duckboat',
#  'recrystallize',
#  'hatefulness',
#  'rhizocaulus',
#  'feedway',
#  'contentful',
#  'shatterer',
#  'frederic',
#  'equity',
#  'beerily',
#  'otolithidae',
#  'sepultural',
#  'unadulterately',
#  'tomatillo',
#  'impenitentness',
#  'gau',
#  'chemesthesis',
#  'jactitation',
#  'whimperingly',
#  'urobilinogenuria',
#  'antifederalism',
#  'diluvium',
#  'perquisite',
#  'periscopic',
#  'trimellitic',
#  'worsement',
#  'tempest',
#  'imprecant',
#  'interrogational',
#  'schappe',
#  'subnote',
#  'menagerie',
#  'lemurinae',
#  'washy',
#  'resumability',
#  'gaddishness',
#  'nonwrinkleable',
#  'alemite',
#  'legitimistic',
#  'themelet',
#  'kherwarian',
#  'stereoscopism',
#  'utterancy',
#  'rebudget',
#  'frumpishly',
#  'prealtar',
#  'rancidification',
#  'unslaughtered',
#  'unwrapper',
#  'connaught',
#  'constitutionalization',
#  'excriminate',
#  'garrison',
#  'rouser',
#  'sexradiate',
#  'unconfined',
#  'trophonucleus',
#  'tuscan',
#  'sawish',
#  'tariffite',
#  'eupatorium',
#  'crepitous',
#  'macrosporophyll',
#  'matchboarding',
#  'exemplify',
#  'quadrate',
#  'cryptocarpic',
#  'rhododendron',
#  'tumatukuru',
#  'riverway',
#  'leviable',
#  'oboist',
#  'tiddler',
#  'otioseness',
#  'trabant',
#  'aswoon',
#  'involucriform',
#  'repassage',
#  'sinlessly',
#  'polynucleolar',
#  'anemobiagraph',
#  'buccula',
#  'galeopithecus',
#  'suboffice',
#  'tamlung',
#  'undenominational',
#  'amblydactyla',
#  'babuism',
#  'freight',
#  'occamist',
#  'lieutenant',
#  'esoterism',
#  'sperm',
#  'dilemi',
#  'untramped',
#  'pissant',
#  'unicornuted',
#  'bobcoat',
#  'sphaerocarpaceae',
#  'hadean',
#  'symphonetic',
#  'sulfuration',
#  'evacuee',
#  'throttler',
#  'sillandar',
#  'cosmopolis',
#  'thaumatogeny',
#  'extracted',
#  'nonassentation',
#  'strain',
#  'lionheartedness',
#  'adoptability',
#  'fistulatous',
#  'succinimide',
#  'cloudily',
#  'biopsychologist',
#  'copygraph',
#  'reit',
#  'valleyward',
#  'unfashioned',
#  'archemperor',
#  'pseudaxis',
#  'cookable',
#  'pondfish',
#  'footboard',
#  'coenzyme',
#  'pneumohydropericardium',
#  'engross',
#  'intended',
#  'consummatory',
#  'bombidae',
#  'longilateral',
#  'nasoscope',
#  'paintedness',
#  'semidiapason',
#  'ancistrocladaceae',
#  'osphyalgic',
#  'passival',
#  'jackbird',
#  'awfulness',
#  'opisthognathism',
#  'microstylous',
#  'hubby',
#  'arachnitis',
#  'incontestably',
#  'ambient',
#  'lemanea',
#  'predicational',
#  'leatherflower',
#  'proscholastic',
#  'nonejection',
#  'creammaker',
#  'nontuberculous',
#  'polygenism',
#  'ambler',
#  'hydrocaulus',
#  'infestive',
#  'regulize',
#  'puinavi',
#  'aliency',
#  'bialate',
#  'cavitation',
#  'stereoscopy',
#  'reave',
#  'oliniaceae',
#  'manufacture',
#  'tourn',
#  'aminosis',
#  'uncompliability',
#  'unreticent',
#  'avondbloem',
#  'ornithophile',
#  'vestmental',
#  'ecuadorian',
#  'thonder',
#  'gracelessness',
#  'farmy',
#  'pathogenesy',
#  'spirality',
#  'consumptivity',
#  'peach',
#  'sulphone',
#  'tenesmus',
#  'lymphopenia',
#  'aught',
#  'bouchaleen',
#  'syringomyelia',
#  'antecedent',
#  'murmur',
#  'ericaceous',
#  'predispose',
#  'reabridge',
#  'emperor',
#  'cheiragra',
#  'acratia',
#  'acatastatic',
#  'arecaceae',
#  'dissyllable',
#  'hayloft',
#  'kalmarian',
#  'swindledom',
#  'adenoacanthoma',
#  'snirl',
#  'orage',
#  'extrospective',
#  'unsepulchered',
#  'psammite',
#  'bingle',
#  'cetorhinoid',
#  'chrysophenine',
#  'sulphonal',
#  'anotus',
#  'sacrilege',
#  'symposiastic',
#  'scarer',
#  'albitic',
#  'uncasemated',
#  'foraneous',
#  'hydrocaryaceae',
#  'termitarium',
#  'tomjohn',
#  'reavouch',
#  'thyrocervical',
#  'weatherproofed',
#  'unchallenging',
#  'servetianism',
#  'bolewort',
#  'dongola',
#  'quechua',
#  'acrosome',
#  'schizoidism',
#  'unreplaceable',
#  'foreclaw',
#  'atophan',
#  'mongolization',
#  'princekin',
#  'colipyuria',
#  'recontrast',
#  'hastingsite',
#  'overflood',
#  'stundism',
#  'subtropics',
#  'sheepy',
#  'caatinga',
#  'marigold',
#  'deprivation',
#  'ibidinae',
#  'moneral',
#  'interlie',
#  'carpoptosis',
#  'olefiant',
#  'ovicellular',
#  'cyclization',
#  'uncommenting',
#  'scalpture',
#  'opulently',
#  'legpulling',
#  'playward',
#  'pontlevis',
#  'staroobriadtsi',
#  'whulk',
#  'tyrrhenian',
#  'deathin',
#  'violina',
#  'taxis',
#  'fidejussion',
#  'pseudoromantic',
#  'zymolyis',
#  'mummichog',
#  'gymnure',
#  'matricide',
#  'spindleshanks',
#  'manageress',
#  'lectrice',
#  'behooped',
#  'patesiate',
#  'unambitiousness',
#  'tassah',
#  'repullulation',
#  'nonadornment',
#  'unenlarged',
#  'signalman',
#  'linenette',
#  'breathful',
#  'zoosporocyst',
#  'rumbustiousness',
#  'interosculant',
#  'figged',
#  'pyroxmangite',
#  'betwattled',
#  'zonal',
#  'washbasin',
#  'disinfest',
#  'tomfoolery',
#  'taiver',
#  'opisthoglossal',
#  'undertaking',
#  'hematinometer',
#  'sertulariidae',
#  'homoiothermic',
#  'aplobasalt',
#  'stalemate',
#  'analgic',
#  'vasculature',
#  'unnamability',
#  'preaffirmative',
#  'xylometer',
#  'craniate',
#  'proalcoholism',
#  'anomite',
#  'nonperseverance',
#  'extravaginal',
#  'logogram',
#  'triloculate',
#  'infraclusion',
#  'overcivilize',
#  'mimine',
#  'outtalent',
#  'zoniferous',
#  'superbenign',
#  'sulphocarbamic',
#  'aurir',
#  'falconry',
#  'overpolitic',
#  'intercortical',
#  'membrana',
#  'logarithmetically',
#  'multiloquy',
#  'dysesthetic',
#  'acetol',
#  'areito',
#  'imponderabilia',
#  'crossite',
#  'yataghan',
#  'manzana',
#  'nonstaining',
#  'competent',
#  'unsympathized',
#  'pulsate',
#  'voltametric',
#  'entrainer',
#  'attacapan',
#  'mantuamaker',
#  'renegotiations',
#  'plowshare',
#  'overlooker',
#  'mezcal',
#  'electrocataphoresis',
#  'chinband',
#  'banian',
#  'graffer',
#  'scoffingstock',
#  'heartening',
#  'thoriate',
#  'unwistful',
#  'hydrocores',
#  'dispersonification',
#  'scytheless',
#  'semicentenarian',
#  'haematoxylic',
#  'otosalpinx',
#  'exonship',
#  'helminthosporiose',
#  'palaeoniscoid',
#  'heteroplasia',
#  'muscot',
#  'discountenance',
#  'noncontrivance',
#  'wordmongery',
#  'petrologically',
#  'entelechy',
#  'wieldable',
#  'aggrandizable',
#  'temulently',
#  'dissuasive',
#  'wolffian',
#  'fell',
#  'practicableness',
#  'drag',
#  'slouchiness',
#  'egophonic',
#  'colorectitis',
#  'pulverizer',
#  'sanguineovascular',
#  'situated',
#  'japaconitine',
#  'gapeworm',
#  'swat',
#  'tramman',
#  'utriculoplastic',
#  'orthodiazine',
#  'zambal',
#  'convectional',
#  'sprigged',
#  'lyrichord',
#  'ferryway',
#  'reprobacy',
#  'emball',
#  'dewdropper',
#  'trichoglossine',
#  'nab',
#  'electrodynamic',
#  'peristeromorphic',
#  'desolateness',
#  'praepostorial',
#  'romaika',
#  'philosophobia',
#  'dud',
#  'neddy',
#  'encyst',
#  'preconcertion',
#  'pseudolamellibranchiate',
#  'tsun',
#  'pross',
#  'scorching',
#  'buccinidae',
#  'mediofrontal',
#  'backpedal',
#  'deuce',
#  'urocystitis',
#  'carbanil',
#  'superparasitism',
#  'cycle',
#  'undercrypt',
#  'chiltern',
#  'antepectoral',
#  'aneroid',
#  'dacryolithiasis',
#  'hoggishness',
#  'spicket',
#  'xiphosuridae',
#  'guising',
#  'distich',
#  'cannibalic',
#  'tympanotemporal',
#  'gervais',
#  'hippocoprosterol',
#  'mannerlessness',
#  'misleading',
#  'spellproof',
#  'coonskin',
#  'sexivalent',
#  'grassworm',
#  'discrete',
#  'enthymeme',
#  'zabaglione',
#  'demoid',
#  'tadpolelike',
#  'hydrospire',
#  'leptocephalous',
#  'cataplasm',
#  'middleway',
#  'dadaist',
#  'nondatival',
#  'pyrolignous',
#  'clinodiagonal',
#  'parallelometer',
#  'episodal',
#  'feverishness',
#  'trailsman',
#  'phyllomancy',
#  'oxboy',
#  'radicating',
#  'vintage',
#  'unartful',
#  'neurogram',
#  'cholesterol',
#  'diagrammatical',
#  'restitutory',
#  'coreless',
#  'subordinacy',
#  'zeal',
#  'connellite',
#  'stringing',
#  'dialectal',
#  'multiplet',
#  'unconfiscable',
#  'ornament',
#  'hapu',
#  'richling',
#  'malty',
#  'gayment',
#  'subfossorial',
#  'transubstantiate',
#  'chiasm',
#  'omnitemporal',
#  'unwontedly',
#  'len',
#  'retinitis',
#  'piedmontite',
#  'anthracotherium',
#  'bursiculate',
#  'plangor',
#  'emmental',
#  'catenary',
#  'reedplot',
#  'thermodiffusion',
#  'millenniarism',
#  'prodigus',
#  'snuffles',
#  'station',
#  'shrinkingly',
#  'dragonesque',
#  'aides',
#  'countervaunt',
#  'asta',
#  'nonministration',
#  'oriolus',
#  'undisproved',
#  'boston',
#  'vitrain',
#  'predismissal',
#  'striper',
#  'acclimatizable',
#  'epidiascope',
#  'pipilo',
#  'risibleness',
#  'micrographer',
#  'climatologically',
#  'pensiveness',
#  'obstructively',
#  'renascibleness',
#  'tipcat',
#  'geochronic',
#  'microsauria',
#  'unrepealableness',
#  'undersawyer',
#  'equiponderance',
#  'monomial',
#  'nonvulvar',
#  'abret',
#  'disassimilation',
#  'scrubbiness',
#  'bindery',
#  'pockily',
#  'phraseographic',
#  'crumpled',
#  'zootherapy',
#  'fringillaceous',
#  'bothersome',
#  'rajaship',
#  'gabblement',
#  'cincinnati',
#  'anabasse',
#  'schismatize',
#  'hypoglossitis',
#  'peppiness',
#  'triceratops',
#  'diapophysis',
#  'convictor',
#  'octarchy',
#  'mese',
#  'marquis',
#  'ozonizer',
#  'footway',
#  'nonforested',
#  'ulidian',
#  'depositive',
#  'gratefulness',
#  'fishhouse',
#  'roseless',
#  'writhing',
#  'halterbreak',
#  'teleophore',
#  'bellyland',
#  'ringmaking',
#  'uncontrolled',
#  'spermophore',
#  'poltroonishly',
#  'precomprehend',
#  'boden',
#  'interknit',
#  'tailge',
#  'shivery',
#  'caesardom',
#  'dynametric',
#  'outwing',
#  'quickness',
#  'unblunder',
#  'uncorking',
#  'ecclesiasticus',
#  'latifundian',
#  'tameheartedness',
#  'pinnipedia',
#  'thaspium',
#  'forslow',
#  'filamentary',
#  'geographize',
#  'tripping',
#  'unstroked',
#  'interrupting',
#  'scrawly',
#  'source',
#  'unsingular',
#  'inone',
#  'inanely',
#  'originality',
#  'marl',
#  'paulist',
#  'carburant',
#  'mulberry',
#  'venin',
#  'cassoon',
#  'notoriously',
#  'worldlily',
#  'sinisterness',
#  'jugger',
#  'pensived',
#  'nichelino',
#  'noncosmopolitism',
#  'alary',
#  'fatherhood',
#  'ferntickled',
#  'antialcoholic',
#  'irrepressible',
#  'acerin',
#  'stauroscope',
#  'harmonizable',
#  'parabomb',
#  'healless',
#  'picudo',
#  'pacifier',
#  'massagist',
#  'kindredly',
#  'procoracoidal',
#  'supervisor',
#  'ticktack',
#  'contributorial',
#  'demotics',
#  'convulsively',
#  'studier',
#  'argumentative',
#  'tappaul',
#  'chicane',
#  'cilium',
#  'blastomycete',
#  'drabbler',
#  'nondiagrammatic',
#  'unaffrightedly',
#  'chestily',
#  'cholecystolithiasis',
#  'bowback',
#  'poring',
#  'discipliner',
#  'skeer',
#  'neuron',
#  'shineless',
#  'hyssop',
#  'penetratingly',
#  'capitative',
#  'crackling',
#  'fleet',
#  'preoppress',
#  'stinker',
#  'transfer',
#  'biosocial',
#  'slewed',
#  'incasement',
#  'minionship',
#  'cratometric',
#  'evert',
#  'propayment',
#  'nonchalky',
#  'mucigen',
#  'palatopharyngeus',
#  'searchment',
#  'nonprejudicial',
#  'epigynous',
#  'nonreality',
#  'apadana',
#  'eucommiaceae',
#  'unsegregated',
#  'disbursable',
#  'nurhag',
#  'otopathy',
#  'saboted',
#  'zoodynamic',
#  'developer',
#  'catha',
#  'favoress',
#  'gidgee',
#  'twitchel',
#  'stupefier',
#  'learnedness',
#  'birdlike',
#  'stranglingly',
#  'paracelsist',
#  'corollike',
#  'aftmost',
#  'patroclinic',
#  'dimitry',
#  'unrove',
#  'antirabic',
#  'poltroonism',
#  'fastidiousness',
#  'whirled',
#  'schoolboyish',
#  'dipterad',
#  'shadeless',
#  'idiotic',
#  'procreate',
#  'suffragatory',
#  'costusroot',
#  'tineoidea',
#  'phallic',
#  'sagless',
#  'polecat',
#  'drachmae',
#  'agariciform',
#  'superaccomplished',
#  'disheartenment',
#  'puffball',
#  'fasciation',
#  'gohila',
#  'skilly',
#  'thrinter',
#  'coppernose',
#  'alveololabial',
#  'supersphenoid',
#  'hysterometry',
#  'bolshevist',
#  'orientator',
#  'catmalison',
#  'menuridae',
#  'humanize',
#  'spondylarthritis',
#  'trek',
#  'irregularize',
#  'wellnear',
#  'gruffness',
#  'unstaunchable',
#  'bacbakiri',
#  'macrocephalia',
#  'induplicative',
#  'houri',
#  'sonorousness',
#  'obsede',
#  'idleship',
#  'dimission',
#  'whincheck',
#  'hylomys',
#  'spinicerebellar',
#  'kaldani',
#  'meromyaria',
#  'vainful',
#  'gloam',
#  'introversively',
#  'twelfthly',
#  'regenerative',
#  'ecumenicity',
#  'unbeaued',
#  'supplicantly',
#  'alcalzar',
#  'radman',
#  'terebrate',
#  'amblygonite',
#  'hippoid',
#  'vaporimeter',
#  'whimberry',
#  'panorpidae',
#  'cevennian',
#  'trimeter',
#  'ramulus',
#  'bellware',
#  'nephropore',
#  'goldenhair',
#  'untittering',
#  'aoul',
#  'ribber',
#  'leucoquinizarin',
#  'stockbow',
#  'quatercentenary',
#  'unobsolete',
#  'braided',
#  'sussex',
#  'crout',
#  'wait',
#  'heartsease',
#  'convalescently',
#  'sedum',
#  'unrind',
#  'conveniency',
#  'undisturbedness',
#  'rochet',
#  'outgrowing',
#  'undaily',
#  'ammoniemia',
#  'aglaia',
#  'undetermined',
#  'epistemic',
#  'nisse',
#  'reglorified',
#  'snobography',
#  'unperverse',
#  'archseducer',
#  'bovinity',
#  'duraquara',
#  'foremessenger',
#  'lithophane',
#  'revisitation',
#  'winterdykes',
#  'choriambize',
#  'undisintegrated',
#  'heterocoela',
#  'natal',
#  'deinsularize',
#  'cavina',
#  'remarch',
#  'oxyesthesia',
#  'embarrassment',
#  'rheophoric',
#  'cucurbite',
#  'veneti',
#  'brainache',
#  'utinam',
#  'deva',
#  'whiffling',
#  'inequivalent',
#  'invaluably',
#  'parousia',
#  'isotype',
#  'lila',
#  'strainer',
#  'bendy',
#  'malignity',
#  'adjudicative',
#  'pygobranchiata',
#  'shopwoman',
#  'dialectic',
#  'stegomus',
#  'nondepression',
#  'cerasin',
#  'philodestructiveness',
#  'subreption',
#  'housewifery',
#  'veritist',
#  'female',
#  'zoolatrous',
#  'spellbind',
#  'syllabically',
#  'tyroma',
#  'recarry',
#  'wryneck',
#  'diffractiveness',
#  'phytoteratologist',
#  'clarice',
#  'demicadence',
#  'ankylotic',
#  'waiterage',
#  'blastostylar',
#  'margaric',
#  'domainal',
#  'uprighting',
#  'sculp',
#  'lernaeoid',
#  'shabash',
#  'unthreshed',
#  'ers',
#  'hoodwink',
#  'coxarthrocace',
#  ...]

# %%
wordunique.sort()

# %%
wordunique[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
wordunique[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
wordclean = [word.strip().lower() for word in open('words', 'r')]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordclean = sorted(list(set([word.strip().lower() for word in open('words', 'r')])))

# %%
wordclean[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %% [markdown]
# ### Start Anagram

# %%
sorted('lives')
# Out:
# ['e', 'i', 'l', 's', 'v']

# %%
sorted('lives') == sorted('elvis')
# Out:
# True

# %%
sorted('hate') == sorted('love')
# Out:
# False

# %%
def signature(word):
    return ''.join(sorted(word))

# %%
signature('lives')
# Out:
# 'eilsv'

# %%
'/'.join(['a','b','c'])
# Out:
# 'a/b/c'

# %%
def anagram(myword):
    return [word for word in wordclean if signature(word) == signature(myword)]

# %%
anagram('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
# %timeit anagram('dictionary')
# Out:
# 1 loop, best of 3: 690 ms per loop

# %%
words_bysig = {}
for word in wordclean:
    words_bysig[signature(word)].append(word)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-3719e8f06bad> in <module>()
#       1 words_bysig = {}
#       2 for word in wordclean:
# ----> 3     words_bysig[signature(word)].append(word)
#
# KeyError: 'a'

# %%
import collections

# %%
words_bysig = collections.defaultdict(list)

for word in wordclean:
    words_bysig[signature(word)].append(word)

# %%
words_bysig
# Out:
# defaultdict(list,
#             {'deeelrrssss': ['redressless'],
#              'biioprrss': ['spirorbis'],
#              'acgiilntt': ['latticing'],
#              'aiiillnoqtu': ['illiquation'],
#              'cclnoorty': ['cyclotron'],
#              'ccehiiinopstz': ['cocitizenship'],
#              'adeenorsssv': ['oversadness'],
#              'deipp': ['piped'],
#              'efnorrt': ['fronter', 'refront'],
#              'aceeilllprru': ['pericellular'],
#              'aabbeehiilnnnsstu': ['uninhabitableness'],
#              'ggiinpr': ['griping'],
#              'aaeeghiimstu': ['hemiageustia'],
#              'aaceeelo': ['oleaceae'],
#              'cehioprsty': ['hyperstoic'],
#              'beelmmnrtu': ['rumblement'],
#              'abmos': ['ambos', 'sambo'],
#              'aceghillluu': ['lechuguilla'],
#              'ceeelnrsst': ['centerless'],
#              'aaiknst': ['nastika'],
#              'efirrzz': ['frizzer'],
#              'ceiloostty': ['osteolytic'],
#              'aacdeeirxy': ['xyridaceae'],
#              'adeeefginrrrtu': ['unrefrigerated'],
#              'eghilnt': ['enlight', 'lighten'],
#              'ehllmoopssuy': ['mesophyllous'],
#              'cdeeiiklnr': ['cinderlike'],
#              'aacegggilllooory': ['agrogeologically'],
#              'ehloopty': ['holotype'],
#              'bceeeilnpsssstu': ['susceptibleness'],
#              'afimoqru': ['aquiform'],
#              'iknst': ['stink'],
#              'bcceeiloooprsty': ['electrobioscopy'],
#              'fil': ['lif'],
#              'aceilnortu': ['ulceration'],
#              'deeffnor': ['offender', 'reoffend'],
#              'aeeglnost': ['stonegale'],
#              'aaegilloopty': ['palaetiology'],
#              'aabenortu': ['nearabout'],
#              'achimnnoru': ['unharmonic'],
#              'aaelllptu': ['patellula'],
#              'ceiklnosu': ['nickelous'],
#              'aaikmnst': ['antimask'],
#              'aceeehmmoorttty': ['hematocytometer'],
#              'eeegiiknnosst': ['kinetogenesis'],
#              'aacimprsst': ['spartacism'],
#              'aceiortvx': ['evocatrix'],
#              'aceemnntt': ['enactment'],
#              'abdeeilmprsu': ['subepidermal'],
#              'eeinnptwy': ['witepenny'],
#              'eeimnnt': ['eminent'],
#              'aaeimnopsstu': ['apneumatosis'],
#              'ceiklnortuu': ['uncourtlike'],
#              'abfimoorrr': ['arboriform'],
#              'eeiiklqtu': ['quietlike'],
#              'eeehiklst': ['sheetlike'],
#              'eeilnpsvy': ['pensively'],
#              'bbeirry': ['bribery'],
#              'binoorstu': ['obtrusion'],
#              'abehlsst': ['bathless'],
#              'acddhiorrs': ['disorchard'],
#              'cfllnorsuy': ['scornfully'],
#              'ciiilmpsty': ['simplicity'],
#              'ehjops': ['joseph'],
#              'acdinnooortt': ['triconodonta'],
#              'aaddeeeeehlnnrsst': ['leadenheartedness'],
#              'ahimmnoru': ['harmonium'],
#              'aaloprt': ['atropal'],
#              'uv': ['vu'],
#              'aennooppr': ['propanone'],
#              'acdehilorz': ['chlorazide'],
#              'accceiiilost': ['silicoacetic'],
#              'aachop': ['apocha'],
#              'cddiioty': ['dictyoid'],
#              'acefgiinnorttu': ['centrifugation'],
#              'ccehilot': ['helcotic', 'lochetic', 'ochletic'],
#              'eeiilllorssst': ['listerellosis'],
#              'lorstuuuv': ['vulturous'],
#              'aehinopru': ['auriphone'],
#              'aabcln': ['bancal', 'blanca'],
#              'abekst': ['basket', 'betask'],
#              'deegiiinnrsstt': ['disinteresting'],
#              'aahiksw': ['washaki'],
#              'ahikns': ['naskhi'],
#              'eeimrstyz': ['mysterize'],
#              'aadgimnnooprrsu': ['androsporangium'],
#              'adekmors': ['darksome'],
#              'addeeorstx': ['extradosed'],
#              'ceeilorstu': ['reticulose'],
#              'acdeehiilnop': ['ophicleidean'],
#              'abcllnoosy': ['consolably'],
#              'aclnopry': ['capronyl'],
#              'aeirttx': ['extrait'],
#              'aeeehnprsst': ['parentheses'],
#              'bdegiinorry': ['indigoberry'],
#              'dehinpssttu': ['studentship'],
#              'abcdeiilopt': ['diaboleptic'],
#              'acdemmmno': ['commendam'],
#              'cdhiiilmu': ['chilidium'],
#              'abderryy': ['dayberry'],
#              'addeeeimnrstu': ['semidenatured'],
#              'cekoprst': ['prestock', 'sprocket'],
#              'fimnoprru': ['pruniform'],
#              'chiilnooprrsstuu': ['nitrososulphuric'],
#              'ainy': ['ayin'],
#              'addmnu': ['dudman'],
#              'adehinos': ['adhesion'],
#              'aaegimrrt': ['margarite'],
#              'eflort': ['floret', 'forlet', 'lofter', 'torfel'],
#              'aemmrrst': ['strammer'],
#              'abeeelnrt': ['enterable'],
#              'adeenrrsstt': ['transdesert'],
#              'bccilmruuu': ['crucibulum'],
#              'adegiillnntu': ['dentilingual', 'indulgential', 'linguidental'],
#              'aeeiimnorssty': ['enteromyiasis'],
#              'eghlnt': ['length'],
#              'adeeeemmnprtt': ['temperamented'],
#              'aceerrstt': ['scatterer', 'streetcar'],
#              'abdeeeflrr': ['deferrable'],
#              'eefillmosy': ['lifesomely'],
#              'aeflru': ['earful', 'farleu', 'ferula'],
#              'aaffgilrsu': ['suffragial'],
#              'abcciillnoy': ['biconically'],
#              'aahiknsstt': ['tashnakist'],
#              'acdfiiilnoptu': ['duplification'],
#              'aaeelquv': ['equaeval'],
#              'accdgimnoooorrssttyyyy': ['dacryocystosyringotomy'],
#              'afimmoqrsu': ['squamiform'],
#              'cceimrty': ['mycteric'],
#              'aabeehnr': ['hebraean'],
#              'adeeirsv': ['readvise'],
#              'aaefilnooprrtt': ['frontoparietal', 'parietofrontal'],
#              'diioprty': ['pityroid', 'pyritoid'],
#              'eeeeghinortty': ['heterogeneity'],
#              'eeefhorrw': ['wherefore'],
#              'aahiirrs': ['harrisia'],
#              'abeegglor': ['gorgeable'],
#              'bceeimnopry': ['epembryonic'],
#              'ceeeinopprrt': ['reperception'],
#              'aaabimnorz': ['mozarabian'],
#              'aehkoorv': ['ravehook'],
#              'aacnooprsu': ['anocarpous'],
#              'aaccghiillmoooprt': ['micropathological'],
#              'aaeghmmprt': ['metaphragm'],
#              'adilmnopruy': ['polyandrium'],
#              'aabgnuw': ['wabunga'],
#              'aaacdeilllmmorty': ['melodramatically'],
#              'eimmnr': ['nimmer'],
#              'accfiip': ['pacific'],
#              'abcdkloow': ['blackwood'],
#              'ddegioz': ['goddize'],
#              'diks': ['disk', 'kids', 'skid'],
#              'adeilntu': ['nidulate', 'untailed'],
#              'deeiissz': ['disseize'],
#              'aceekmorr': ['coremaker'],
#              'aelnnptwy': ['twalpenny'],
#              'abdenoprtu': ['unprobated'],
#              'aaailmopsstt': ['mastoplastia'],
#              'hiinoorsst': ['ornithosis'],
#              'aacchilmnor': ['monarchical'],
#              'eeehkrt': ['theeker'],
#              'aaghimprr': ['marigraph'],
#              'egiinrtu': ['intrigue', 'tigurine'],
#              'adeilsu': ['sulidae'],
#              'aiimnopttu': ['imputation'],
#              'aceellrrstu': ['craterellus'],
#              'aacilrruu': ['auricular'],
#              'aabeelnntt': ['tenantable'],
#              'aaglnrru': ['granular'],
#              'ehikl': ['kileh'],
#              'almop': ['mopla', 'palmo'],
#              'aaefgikmns': ['safemaking'],
#              'aaceilllsty': ['elastically'],
#              'eefhoorrsw': ['foreshower'],
#              'deflnooow': ['felonwood'],
#              'aaddeeiloru': ['aleurodidae'],
#              'aciinnop': ['panionic'],
#              'ceelrsstu': ['cutleress', 'lecturess', 'truceless'],
#              'fgiinnttu': ['unfitting'],
#              'bccefllooorrsstuuuu': ['scrofulotuberculous'],
#              'egginnorss': ['engrossing'],
#              'abeeinnopsttu': ['obtusipennate'],
#              'abdeeeelnssstt': ['detestableness'],
#              'aeekmmrry': ['merrymake'],
#              'elnorvy': ['novelry'],
#              'ccdiiotty': ['dictyotic'],
#              'aaceghiimnoprstt': ['cinematographist'],
#              'acccdiino': ['coccidian'],
#              'aabdegort': ['goatbeard'],
#              'aeklny': ['alkyne'],
#              'aaccilnoos': ['occasional'],
#              'aeeinnnossssstuu': ['antisensuousness'],
#              'aceehilnorss': ['heroicalness'],
#              'accehiilmmorrsttu': ['ultramicrochemist'],
#              'accghimnoopr': ['phragmoconic'],
#              'beelorsttuvy': ['oversubtlety'],
#              'eeflooprst': ['sleetproof', 'steelproof'],
#              'aeklt': ['ketal'],
#              'bdeeiilnnnuz': ['benzinduline'],
#              'eegpr': ['repeg'],
#              'lpru': ['purl'],
#              'adhooprrt': ['arthropod'],
#              'acehilnorsssuv': ['chivalrousness'],
#              'aaadelnprt': ['paradental'],
#              'acceiilmmorst': ['commercialist'],
#              'aairtv': ['tarvia'],
#              'aeiinrt': ['inertia'],
#              'aabcmtu': ['tabacum'],
#              'eehinosuw': ['winehouse'],
#              'eefillrstt': ['filletster'],
#              'aabeiilnrrrsty': ['irrestrainably'],
#              'bcceiiijosttv': ['objectivistic'],
#              'aadenz': ['azande'],
#              'adiimmmnou': ['diammonium'],
#              'dehijmno': ['demijohn'],
#              'aeinooprssu': ['aponeurosis'],
#              'aaaceilnpsu': ['aesculapian'],
#              'apss': ['pass'],
#              'aaceillllmty': ['metallically'],
#              'acehiktu': ['takeuchi'],
#              'aaadiinnoptt': ['inadaptation'],
#              'adelstt': ['slatted'],
#              'aefgnorst': ['aftersong'],
#              'aghloppryy': ['polygraphy'],
#              'beir': ['beri', 'bier', 'brei', 'ribe'],
#              'cdeeghinnoorss': ['chondrogenesis'],
#              'adeeknprrss': ['predarkness'],
#              'abcrssttu': ['substract'],
#              'adejllop': ['jalloped'],
#              'aacdlpr': ['placard'],
#              'aceinstv': ['cistvaen', 'vesicant'],
#              'aaaabceilllnoopty': ['palaeobotanically'],
#              'aaciiinnnorstt': ['incarnationist'],
#              'aaachioprt': ['cataphoria'],
#              'abhorrsuw': ['arrowbush'],
#              'aacceilnnossu': ['unaccessional'],
#              'ceeeinprst': ['spencerite'],
#              'aeiqrrstu': ['trisquare'],
#              'adeginrrw': ['rewarding'],
#              'adeeilmm': ['ammelide'],
#              'adegilnnoruyz': ['unorganizedly'],
#              'cdeknor': ['dorneck'],
#              'aefgnrstu': ['afterguns', 'transfuge'],
#              'aemnorrtuy': ['uranometry'],
#              'agilmooossttt': ['stomatologist'],
#              'aeeilmnnt': ['lineament', 'manteline'],
#              'aillorttuy': ['tutorially'],
#              'ceehilnnorty': ['incoherently'],
#              'aeeglrrsu': ['regulares'],
#              'aaabelllmmo': ['ambomalleal'],
#              'aaaellnnt': ['annellata'],
#              'eggiinnosu': ['ignigenous'],
#              'cehiooprx': ['exophoric'],
#              'ekrrsy': ['skerry'],
#              'aacinooprrrstty': ['procrastinatory'],
#              'aegiostx': ['geotaxis'],
#              'cefhlllooosw': ['schoolfellow'],
#              'achillopsy': ['sophically'],
#              'aaddeeiilo': ['aeolididae'],
#              'aacghiorrstt': ['gastrotricha'],
#              'aceggiilnoo': ['geologician'],
#              'aaacddeeehnprtty': ['pentadecahydrate'],
#              'adgiilllnnotuy': ['longitudinally'],
#              'acehhinnny': ['hyenanchin'],
#              'aabbbelnnoors': ['nonabsorbable'],
#              'degiinnopsuu': ['pinguedinous'],
#              'adehijps': ['jadeship'],
#              'aovw': ['avow'],
#              'ceelmnntu': ['unclement'],
#              'aadgimoru': ['audiogram'],
#              'aeehiilnopprsstt': ['steprelationship'],
#              'aaceglosu': ['coagulase'],
#              'aelotuyz': ['autolyze'],
#              'ahinprsy': ['syrphian'],
#              'hhilmmooprsy': ['hylomorphism'],
#              'agjknorru': ['kurrajong'],
#              'aacceerrt': ['carcerate'],
#              'aabeilnnptu': ['unpaintable'],
#              'adelntuu': ['undulate'],
#              'cgilmnuu': ['cingulum', 'glucinum'],
#              'aacdeeehnrrtv': ['cravenhearted'],
#              'aeeorrvwy': ['overweary'],
#              'aabhintt': ['habitant'],
#              'adeiinoprsttu': ['disreputation'],
#              'aeiilllmmstttu': ['multimetallist'],
#              'eeghilnnsss': ['englishness'],
#              'bbdehorrruy': ['hydrorubber'],
#              'aehiimnot': ['hiemation'],
#              'aiiimopprrrtx': ['impropriatrix'],
#              'acdefiiorty': ['deificatory', 'edificatory'],
#              'abccikrst': ['crabstick'],
#              'aaeimnoprt': ['atropamine'],
#              'aegiimnnssttuyz': ['unsystematizing'],
#              'aaaaeelmnqu': ['aquaemanale'],
#              'aammuz': ['mazuma'],
#              'aciiilnoprstv': ['provincialist'],
#              'aaeiinopttx': ['expatiation'],
#              'hhilooppstuy': ['phytophilous'],
#              'aegiimnoprt': ['impignorate'],
#              'ahiklpstw': ['whipstalk'],
#              'cccceeinnopsu': ['concupiscence'],
#              'aeeiilnnoprtttv': ['ventripotential'],
#              'aeeltty': ['layette'],
#              'eeimnstuz': ['mezentius'],
#              'elrtuuv': ['vulture'],
#              'aabeiiilmnrrst': ['libertarianism'],
#              'ellooortwy': ['yellowroot'],
#              'acellnnrtuy': ['uncentrally'],
#              'defilnoow': ['elfinwood'],
#              'ghhiops': ['hogship'],
#              'cccdeilmnooopsuy': ['pseudomonocyclic'],
#              'adhmoprrtu': ['podarthrum'],
#              'eeghiloortz': ['theologizer'],
#              'adiilmnno': ['mandilion'],
#              'aabegillnu': ['galbulinae'],
#              'abddehmu': ['dumbhead'],
#              'aceeflprrttu': ['ultraperfect'],
#              'acelmooostu': ['coelomatous'],
#              'eenrt': ['enter', 'neter', 'renet', 'terne', 'treen'],
#              'biimn': ['nimbi'],
#              'addeenorsv': ['oversanded'],
#              'hlmooosstuy': ['homostylous'],
#              'adeeeeefhnrrsst': ['freeheartedness'],
#              'aeiimmnnoppstt': ['misappointment'],
#              'adeiirsuv': ['audiviser'],
#              'aaehinopst': ['asiphonate', 'asthenopia'],
#              'adeegint': ['gedanite'],
#              'beoost': ['besoot', 'bootes'],
#              'aceitv': ['active'],
#              'acejlory': ['cajolery'],
#              'aaceeehkps': ['chesapeake'],
#              'imoorstt': ['motorist'],
#              'abddeelmo': ['beadledom'],
#              'eegilmnorz': ['mongrelize'],
#              'diillqsu': ['squillid'],
#              'cdlnooru': ['couldron'],
#              'aabccekprrs': ['backscraper'],
#              'aacghoprrt': ['cartograph'],
#              'acfiknrss': ['scarfskin'],
#              'aceelnorstuy': ['nectareously'],
#              'aceilnnpqqtuuu': ['quinquepunctal'],
#              'adhnorsuy': ['anhydrous'],
#              'aadeeinoxy': ['oxyaenidae'],
#              'ghiinrtw': ['writhing'],
#              'acilmot': ['comital'],
#              'acenosssttu': ['outcastness'],
#              'deeeiptx': ['expedite'],
#              'cnosu': ['conus'],
#              'ciiorstty': ['toryistic'],
#              'aacdeilno': ['caledonia', 'laodicean'],
#              'eeeilsvwy': ['swiveleye'],
#              'aabcdlsuu': ['subcaudal'],
#              'aaceehmnortttv': ['overattachment'],
#              'aadghnoopt': ['gnathopoda'],
#              'acdhiinorssy': ['cyanhidrosis'],
#              'acdiiijlnu': ['injudicial'],
#              'aaccdehnorry': ['archdeaconry'],
#              'cehkn': ['kench'],
#              'acmop': ['campo'],
#              'ceenoorttuv': ['countervote'],
#              'deeiilmns': ['semilined'],
#              'chioooprrs': ['criophoros'],
#              'aaaalmpy': ['ampalaya'],
#              'acehiilmorst': ['isothermical'],
#              'acefiiinortv': ['verification'],
#              'abdehiinnrt': ['thinbrained'],
#              'aeimorrsstu': ['amortisseur'],
#              'acdiilru': ['dialuric'],
#              'dehoopr': ['redhoop', 'rhodope'],
#              'aaccmu': ['macuca'],
#              'achilnos': ['lichanos', 'nicholas'],
#              'aachhilmrrty': ['arrhythmical'],
#              'acdfioopr': ['acidproof'],
#              'adiiioprstt': ['parotiditis'],
#              'eghnuy': ['gunyeh'],
#              'aceegimnnoot': ['monogenetica'],
#              'adehinnss': ['handiness'],
#              'cgimnostu': ['costuming'],
#              'abeennnrrssu': ['unbarrenness'],
#              'aagiiinoorrttu': ['autoirrigation'],
#              'allly': ['allyl'],
#              'aeilnprsstu': ['septinsular'],
#              'aaabrz': ['bazaar'],
#              'aorrst': ['rostra', 'sartor'],
#              'aacceilnopptt': ['antapoplectic'],
#              'aaccefhiiinoprt': ['preachification'],
#              'iinorssstu': ['sinistrous'],
#              'abcehiimortz': ['bichromatize'],
#              'ceeefillrtvy': ['reflectively'],
#              'aacegimnopt': ['compaginate'],
#              'ijlm': ['mijl'],
#              'aabcilnnnotuy': ['uncontainably'],
#              'adghiorrrssyy': ['hydrargyrosis'],
#              'bdeeilrzz': ['bedrizzle'],
#              'eeipprrrssu': ['presurprise'],
#              'ainppry': ['papyrin'],
#              'aagglr': ['laggar'],
#              'adegnotw': ['downgate'],
#              'aeilqsuy': ['queasily'],
#              'cceghiknrst': ['checkstring'],
#              'abcceilnnoosu': ['unconsociable'],
#              'nors': ['sorn'],
#              'cdehiimmooors': ['chromidiosome'],
#              'aefkoopqrsu': ['squeakproof'],
#              'acemopprrs': ['carposperm', 'spermocarp'],
#              'aeeffhorrt': ['forefather'],
#              'aabhv': ['bhava'],
#              'aabcdelort': ['carbolated'],
#              'aeefhimnprs': ['freemanship'],
#              'adlnoor': ['orlando'],
#              'accdiiinnoot': ['coindication'],
#              'aacehilmmoorru': ['acromiohumeral'],
#              'morsty': ['stormy'],
#              'aacchinorrstt': ['transthoracic'],
#              'abcfiinortu': ['bifurcation'],
#              'aaintt': ['attain', 'tatian'],
#              'bdelloow': ['bellwood'],
#              'adeiiilrt': ['idrialite'],
#              'aiiiloopprrtty': ['propitiatorily'],
#              'aaaghiillooprt': ['allotriophagia'],
#              'acimnooprsty': ['trypanosomic'],
#              'bciinoorsstttu': ['obstructionist'],
#              'aabcehilnoprty': ['polybranchiate'],
#              'aaiillnopt': ['palliation'],
#              'behilost': ['sebolith'],
#              'eort': ['rote', 'tore'],
#              'eeeelnnssssss': ['senselessness'],
#              'eeehhikopprss': ['shopkeeperish'],
#              'acillllooquy': ['colloquially'],
#              'adhiimorsty': ['athyroidism'],
#              'chimmnoors': ['monorchism'],
#              'aissst': ['assist', 'stasis'],
#              'aeggillnnnty': ['entanglingly'],
#              'dehiloppry': ['hyperploid'],
#              'aceegiortz': ['categorize'],
#              'ahlloty': ['loathly', 'tallyho'],
#              'behmrtu': ['thumber'],
#              'acnoorst': ['ostracon', 'socotran'],
#              'bbiiilnru': ['bilirubin'],
#              'ceelrsu': ['luceres', 'recluse'],
#              'ceeiipprsttvy': ['perspectivity'],
#              'bmnouux': ['unbuxom'],
#              'aaeelmmnrttt': ['maltreatment'],
#              'aabeelnnss': ['albanenses'],
#              'aeeiirtvz': ['vizierate'],
#              'ghiikrz': ['kirghiz'],
#              'aaegmttw': ['megawatt'],
#              'cceegilnoty': ['gynecotelic'],
#              'aaceilnnr': ['carnelian', 'encranial'],
#              'acgiillmnosuuy': ['mucilaginously'],
#              'degiloopst': ['pedologist'],
#              'acefikrtu': ['fruitcake'],
#              'acdelmsu': ['muscadel'],
#              'bdeeggru': ['begrudge'],
#              'abimsu': ['iambus'],
#              'elorttt': ['trotlet'],
#              'acmmprsu': ['scrampum'],
#              'belowz': ['blowze'],
#              'aeenstt': ['enstate'],
#              'eeiimnnortu': ['munitioneer'],
#              'aeegst': ['egesta'],
#              'einnosstt': ['sonnetist'],
#              'aceinnorz': ['canonizer'],
#              'adennooprrty': ['nonpredatory'],
#              'eeioprrsssuu': ['superserious'],
#              'ceostw': ['stowce'],
#              'abdeeiillnrtu': ['turbinellidae'],
#              'aaceiiinnnopttv': ['nonanticipative'],
#              'aaghhilopry': ['haliography'],
#              'aacdehnp': ['panached'],
#              'aceeghimmnorstty': ['magnetochemistry'],
#              'aabcilnnossttu': ['consubstantial'],
#              'acghhinnu': ['haunching'],
#              'cimootuyz': ['zoocytium'],
#              'abeehiiilnpprsty': ['apprehensibility'],
#              'egmosstu': ['stegomus'],
#              'aefkorrs': ['forsaker'],
#              'eeefnrss': ['freeness'],
#              'aaacilnprst': ['transapical'],
#              'aadlmno': ['mandola', 'odalman'],
#              'csttuy': ['scutty'],
#              'cdefhit': ['fitched'],
#              'ceot': ['cote', 'teco'],
#              'aailmmns': ['lamanism'],
#              'aceeinrsstu': ['neurectasis'],
#              'dehimoorssst': ['mistresshood'],
#              'abeilnrrttuu': ['intertubular'],
#              'chiilnooopps': ['opsonophilic'],
#              'accghhiillloooppssyyy': ['psychophysiologically'],
#              'adeiinqsttu': ['equidistant'],
#              'beeilmnorv': ['overnimble'],
#              'cefinnooprssuu': ['superconfusion'],
#              'ceeilnooprst': ['selenotropic'],
#              'afiiilmnnost': ['inflationism'],
#              'achlrsy': ['chrysal'],
#              'aiinnosv': ['invasion'],
#              'ccceeilnnot': ['noneclectic'],
#              'cdeeeeinprssv': ['perceivedness'],
#              'eghillnsssu': ['gullishness'],
#              'aacehiprsuy': ['hyperacusia'],
#              'aefiinoorttux': ['uterofixation'],
#              'cegilmooty': ['etymologic'],
#              'aaeiilnnorttuz': ['neutralization'],
#              'amsu': ['masu', 'musa', 'saum'],
#              'aginvw': ['waving'],
#              'ceeehinrss': ['cheeriness'],
#              'aiimmnortu': ['immuration'],
#              'aceehortv': ['overteach'],
#              'ceeeellorstt': ['electrosteel'],
#              'aacciinnnnootv': ['nonvaccination'],
#              'aahikmno': ['mokihana'],
#              'cdeelptu': ['decuplet'],
#              'aaabeefnor': ['neofabraea'],
#              'aabccelnostu': ['unaccostable'],
#              'cddfilorsu': ['discordful'],
#              'aaaclmnpu': ['campanula'],
#              'eeinrsstt': ['triteness'],
#              'aabeilnprsu': ['unpraisable'],
#              'adertv': ['advert'],
#              'abeegilmnnsu': ['submeningeal'],
#              'efhrsttu': ['furthest'],
#              'adenry': ['denary', 'yander'],
#              'aahlnnopst': ['nonasphalt'],
#              'ilopptuu': ['outpupil'],
#              'cehiloooopsstu': ['opisthocoelous'],
#              'aceehn': ['achene'],
#              'adeemrsuvx': ['exadversum'],
#              'acceeiinopprssssu': ['perspicaciousness'],
#              'aeghlmnooors': ['hormogonales'],
#              'acdehnoorsuy': ['hydnoraceous'],
#              'abeellnoprux': ['unexplorable'],
#              'beehilopprssst': ['phlebostrepsis'],
#              'ccchiilnoprssuuu': ['succinosulphuric'],
#              'cdeiimnorstu': ['reductionism'],
#              'adehipprs': ['sapphired'],
#              'ccdeenrruy': ['decurrency', 'recrudency'],
#              'acchilnopsuy': ['sulphocyanic'],
#              'aacfgnrry': ['fragrancy'],
#              'aciil': ['cilia', 'iliac'],
#              'deeiillopt': ['lepidolite'],
#              'aaceffinott': ['affectation'],
#              'aacelprtty': ['calyptrate'],
#              'aacdeinvv': ['advancive'],
#              'aaeiirrsst': ['arteriasis'],
#              'aadffiinopr': ['paraffinoid'],
#              'acdeklo': ['cloaked'],
#              'ainnopptu': ['unappoint'],
#              'aeiilmnopswy': ['olympianwise'],
#              'aaddirv': ['dravida'],
#              'adeinor': ['aneroid', 'arenoid'],
#              'aeeillrstvy': ['versatilely'],
#              'aceeemmnorrsty': ['macromesentery'],
#              'cinorsu': ['orcinus'],
#              'acddeeiinnoorst': ['deconsideration'],
#              'aadilortt': ['dilatator'],
#              'aabciqstuu': ['subaquatic'],
#              'cdeilnootuv': ['levoduction'],
#              'aceerrst': ['recaster'],
#              'aabcirssssu': ['bassariscus'],
#              'acceeprrsuu': ['superaccrue'],
#              'acdeehkny': ['hackneyed'],
#              'aabst': ['basta', 'staab'],
#              'acceehilln': ['elenchical'],
#              'eijlmttu': ['multijet'],
#              'belooprt': ['boltrope'],
#              'accehioprsstuy': ['hyperacoustics'],
#              'ccehkrsttuy': ['treckschuyt'],
#              'cdeehinoprruy': ['hydrocupreine'],
#              'aimqrstuu': ['utraquism'],
#              'aaaceegilno': ['loganiaceae'],
#              'aeghinz': ['genizah'],
#              'aabceinnosstttu': ['consubstantiate'],
#              'emrt': ['term'],
#              'aeeghlnn': ['neelghan'],
#              'accejkrsw': ['jackscrew'],
#              'aeeiknorst': ['keratinose'],
#              'acdeegilot': ['geodetical'],
#              'eeeegrstu': ['euergetes'],
#              'imnosyy': ['isonymy'],
#              'aceehinpprrst': ['carpentership'],
#              'ailnsttu': ['lutanist'],
#              'acdhoorru': ['urochorda'],
#              'beflouw': ['beowulf'],
#              'acffghilny': ['chaffingly'],
#              'cefint': ['infect'],
#              'begiiiilllty': ['illegibility'],
#              'aaemmmnrr': ['rammerman'],
#              'cefilmoopr': ['ploceiform'],
#              'acefnprt': ['pencraft'],
#              'afimrsttu': ['tartufism'],
#              'aaciloprs': ['prosaical'],
#              'aaagiilmnnoortz': ['malorganization'],
#              'agiinortv': ['virgation'],
#              'ceiirrsttx': ['trisectrix'],
#              'eegghiilnnnt': ['enlightening'],
#              'eelmoprtu': ['petroleum'],
#              'accehirsttt': ['catstitcher'],
#              'aceorrstu': ['craterous', 'recusator'],
#              'eiloprsuvy': ['perviously', 'previously', 'viperously'],
#              'bceeeinrt': ['terebenic'],
#              'cefiilnru': ['luciferin'],
#              'acdelnor': ['colander'],
#              'aaacmrss': ['macassar'],
#              'acghinpw': ['chingpaw'],
#              'eefiilmnny': ['femininely'],
#              'adeffghilnrtuy': ['unaffrightedly'],
#              'degilly': ['gelidly'],
#              'aceehmmnsy': ['mesenchyma'],
#              'adgimnors': ['dragonism'],
#              'acilsss': ['classis'],
#              'aeinntuxy': ['unanxiety'],
#              'cddemoosu': ['demodocus'],
#              'accdhilorv': ['clavichord'],
#              'adehhiiiooprst': ['histiophoridae'],
#              'ceeelrtt': ['electret', 'tercelet'],
#              'ccghiooprsy': ['hygroscopic'],
#              'abbejr': ['jabber'],
#              'ortu': ['rout', 'toru', 'tour'],
#              'ceeoprtx': ['exceptor'],
#              'aaaddeghhnpry': ['hydradephagan'],
#              'accefiiilmnooptx': ['complexification'],
#              'ddeilt': ['tiddle'],
#              'aaeghimnoorrst': ['stomenorrhagia'],
#              'aeeiprssv': ['aspersive'],
#              'aabeggnoqtu': ['bontequagga'],
#              'aeiilorst': ['solitaire'],
#              'deiooppw': ['pipewood'],
#              'aceelrsv': ['cleavers'],
#              'aeehlnop': ['anophele'],
#              'cgilnttuy': ['cuttingly'],
#              'acdeiorstz': ['castorized'],
#              'accchiir': ['chicaric'],
#              'adeillnors': ['sordellina'],
#              'ceehoprtty': ['trephocyte'],
#              'ccdemotu': ['decoctum'],
#              'aaceinoprrstttu': ['superattraction'],
#              'aadhmv': ['madhva'],
#              'aeillmnpuz': ['pullmanize'],
#              'aadfhlnrw': ['wharfland'],
#              'aeeeilmnnprtux': ['unexperimental'],
#              'adgiinsst': ['angdistis'],
#              'aacdeeiinnprt': ['pentacrinidae'],
#              'aacdehhllmoopsuy': ['haplochlamydeous'],
#              'adeeiiloprsttuux': ['ultraexpeditious'],
#              'egimnorst': ['gerontism', 'monergist'],
#              'corsuuv': ['curvous'],
#              'aaeehipsst': ['apesthesia'],
#              'abeegilnorrt': ['interrogable'],
#              'adeeeglnrtu': ['underlegate', 'unrelegated'],
#              'beeiillnrt': ['interlibel'],
#              'ceeeffitv': ['effective'],
#              'aaceinttu': ['inactuate'],
#              'ahiloprst': ['astrophil'],
#              'efimnortt': ['tentiform'],
#              'abcdehimnorxyz': ['benzhydroxamic'],
#              'ghlmnoooosuy': ['homogonously'],
#              'abdeeiilnnnoort': ['nondeliberation'],
#              'defiinorr': ['diferrion'],
#              'aachiinprstt': ['antiphrastic'],
#              'bhilmostt': ['boltsmith'],
#              'abeinoorsstu': ['broussonetia'],
#              'aeefgilnrss': ['fragileness'],
#              'agilmoosty': ['mayologist'],
#              'aabceeiillprty': ['replaceability'],
#              'aaeiklrrtt': ['tartarlike'],
#              'aefllsy': ['falsely'],
#              'adhillot': ['thalloid'],
#              'aaainorstux': ['stauraxonia'],
#              'acdegiinop': ['adipogenic'],
#              'adeeellrvy': ['revealedly'],
#              'gmmuy': ['gummy'],
#              'acehhilloppr': ['phallephoric'],
#              'hnrtuu': ['unhurt', 'unruth'],
#              'efgiinnprs': ['fingerspin'],
#              'aagggmnoop': ['pogamoggan'],
#              'ceefiorrrsuuv': ['verruciferous'],
#              'ceimnoost': ['economist', 'mesotonic'],
#              'cefimrttuu': ['fruticetum'],
#              'aimnossx': ['saxonism'],
#              'abiilnnnooot': ['nonabolition'],
#              'aadegilnrsw': ['garlandwise'],
#              'aacdilmmopprsty': ['pamprodactylism'],
#              'deginossst': ['stodginess'],
#              'acdiiinrrsttt': ['intradistrict'],
#              'ejloty': ['joylet'],
#              'bceeiinrrs': ['reinscribe'],
#              'abcceillru': ['circulable'],
#              'abenortt': ['betatron'],
#              'ccehorru': ['croucher'],
#              'ceeiklmot': ['cometlike'],
#              'abegnrsu': ['subrange'],
#              'acfiiilmsst': ['facsimilist'],
#              'acfrty': ['crafty'],
#              'aabeghorr': ['harborage'],
#              'cdhlo': ['chold'],
#              'aeeinntvz': ['venanzite'],
#              'acehhilnott': ['chloanthite'],
#              'acchhiiilrt': ['archilithic'],
#              'abeehinsssst': ['beastishness'],
#              'abehilpruy': ['hyperbulia'],
#              'ccehorrs': ['scorcher'],
#              'aaeennntt': ['antennate'],
#              'aaalllnpt': ['tlapallan'],
#              'deeenrtx': ['extender'],
#              'eeeiinprsssstv': ['persistiveness'],
#              'aaceelossx': ['exoascales'],
#              'eeinqrsu': ['squireen'],
#              'acelnrsuu': ['unsecular'],
#              'aefillortw': ['tailflower'],
#              'acdeilnnuuvz': ['unvulcanized'],
#              'aagghhiopry': ['hagiography'],
#              'agllooprssyy': ['polyglossary'],
#              'aadeiilnorttty': ['traditionately'],
#              'abcceiilnortttuu': ['antituberculotic'],
#              'chikopstw': ['whipstock'],
#              'ceeefimnnnort': ['reconfinement'],
#              'ccehhiilnopt': ['philotechnic'],
#              'accehhioprrty': ['archhypocrite'],
#              'ceeijlssu': ['juiceless'],
#              'acillorrtu': ['trilocular'],
#              'cehhiioprst': ['sephirothic'],
#              'coorty': ['octroy'],
#              'deghilns': ['shingled'],
#              'tttuy': ['tutty'],
#              'cdeiiimnorst': ['misdirection'],
#              'acdeeiilnnnsst': ['incidentalness'],
#              'beelnosttt': ['bottlenest'],
#              'eiinrv': ['nervii'],
#              'eeiiopprstv': ['prepositive'],
#              'adeeiknz': ['nakedize'],
#              'aefiinst': ['fasinite'],
#              'cdhiimors': ['dichroism'],
#              'adess': ['dessa'],
#              'aceemmorr': ['macromere'],
#              'adeimprt': ['preadmit'],
#              'ddegiilssuy': ['disguisedly'],
#              'cdeehloory': ['hydrocoele'],
#              'aeglt': ['aglet', 'galet'],
#              'aaaccdeehhiorrty': ['hydrocharitaceae'],
#              'glmpuy': ['glumpy'],
#              'abdeiklnr': ['drinkable'],
#              'accemoprtu': ['compacture'],
#              'abeggrr': ['bragger'],
#              'egiillnnnssuw': ['unwillingness'],
#              'adiopp': ['doppia'],
#              'aabhhilmptu': ['buphthalmia'],
#              'bciilrtuy': ['lubricity'],
#              'aadiloprsttu': ['adstipulator'],
#              'cekors': ['socker'],
#              'ddeeeeklnorw': ['needleworked'],
#              'afgilrtuy': ['frugality'],
#              'adeelnsu': ['unleased', 'unsealed'],
#              'efiinorrsuu': ['uriniferous'],
#              'adehlsw': ['shawled'],
#              'cdeeennnorsstuv': ['unconvertedness'],
#              'abloortuy': ['tauroboly'],
#              'aaabilltv': ['ablatival'],
#              'aabeiinnoorrstttty': ['barytostrontianite'],
#              'aahiiilnnooorttzz': ['horizontalization'],
#              'egnsu': ['genus', 'negus'],
#              'ddeehlru': ['deludher'],
#              'cehioprsvy': ['overphysic'],
#              'acdenoprr': ['nordcaper'],
#              'ivy': ['ivy'],
#              'aegillmnnoqtuy': ['magniloquently'],
#              'aacdeepru': ['drupaceae'],
#              'accdeeiooorssu': ['dioscoreaceous'],
#              'aeeflmorrtu': ['reformulate'],
#              'ghiloopssuy': ['physiologus'],
#              'aaaccdeeilno': ['cladoniaceae'],
#              'eehiiknssst': ['kinesthesis'],
#              'bcceo': ['bocce'],
#              'abccdeiinu': ['buccinidae'],
#              'aeiilnopsz': ['spaniolize'],
#              'ceeiiooppprrtv': ['proprioceptive'],
#              'aaceiilmnrrtuv': ['antivermicular'],
#              'aachrs': ['achras', 'charas'],
#              'bdehooopry': ['preboyhood'],
#              'eilnnorst': ['nonlister'],
#              'aaabeegghiloooppry': ['palaeobiogeography'],
#              'aaaceennrst': ['anarcestean'],
#              'aaccdeellnt': ['cancellated'],
#              'bddghloouy': ['buddhology'],
#              'hlmoptyyy': ['polymythy'],
#              'aaceehioprssu': ['sphaeriaceous'],
#              'acccehortw': ['cowcatcher'],
#              'dhinotuw': ['whodunit'],
#              'acoortu': ['touraco'],
#              'aeimmnorrttt': ['montmartrite'],
#              'aaglmopsty': ['plastogamy'],
#              'deegilnou': ['euglenoid'],
#              'abcehisttu': ['stubachite'],
#              'aaeggr': ['garage'],
#              'acdehhiiinprtt': ['antidiphtheric'],
#              'ceikty': ['tickey'],
#              'acdsw': ['scawd'],
#              'acdeiimnrtu': ['undiametric'],
#              'aabdgilnnoor': ['longobardian'],
#              'ccddeehlmnooooossttuyy': ['cholecystoduodenostomy',
#               'duodenocholecystostomy'],
#              'ghlosty': ['ghostly'],
#              'aacgghhiiopr': ['hagiographic'],
#              'aaeilnrssstu': ['salutariness'],
#              'aceilorrsttt': ['retrostaltic'],
#              'aeeimpst': ['septemia'],
#              'hilrwy': ['whirly'],
#              'ceiintuz': ['cutinize'],
#              'aadehinoprt': ['anthropidae'],
#              'acdeejkw': ['jackweed'],
#              'abeginortu': ['outbearing'],
#              'hoo': ['oho'],
#              'deeenqsuuz': ['unsqueezed'],
#              'agimmnrt': ['tramming'],
#              'cirssuu': ['sciurus'],
#              'aadiilnort': ['ortalidian'],
#              'cghinoos': ['choosing'],
#              'aglntuy': ['gauntly'],
#              'acennrstuu': ['unrecusant'],
#              'aceillmst': ['metallics'],
#              'acehillnopprtuy': ['unprophetically'],
#              'aadegiilnoz': ['diagonalize'],
#              'bfilnotuu': ['bountiful'],
#              'lorsu': ['slour'],
#              'aacelnsstu': ['actualness'],
#              'agiilmnty': ['malignity'],
#              'ceeinrstt': ['intersect'],
#              'aceiiiinorsttz': ['sericitization'],
#              'degnotu': ['tongued'],
#              'aeeegnors': ['aerogenes'],
#              'acciilnooprst': ['corticospinal'],
#              'gillmooprssy': ['prosyllogism'],
#              'adeirrsuy': ['residuary'],
#              'cegiiiilmstt': ['legitimistic'],
#              'aacdiilss': ['diaclasis'],
#              'aeeilmnnooppruu': ['pleuropneumonia'],
#              'cdeegiiinot': ['idiogenetic'],
#              'aaegrtt': ['garetta', 'rattage', 'regatta'],
#              'bimnrruu': ['muirburn'],
#              'bceeegillnry': ['belligerency'],
#              'adeenorv': ['endeavor'],
#              'eeeilprst': ['peristele'],
#              'aacceiinnortv': ['revaccination'],
#              'acdeiimoprrt': ['madreporitic'],
#              'abcehirtuy': ['eurybathic'],
#              'einoooppprrrstu': ['superproportion'],
#              'aeeginnrrt': ['interregna'],
#              'abddeginr': ['ridgeband'],
#              'cdeeeinopprt': ['predeception'],
#              'aeflrsu': ['refusal'],
#              'abfgilorvy': ['forgivably'],
#              'cceehiiloopt': ['cholepoietic'],
#              'accelooprsuu': ['leucocarpous'],
#              'ddeirstu': ['sturdied'],
#              'acceiiimnnors': ['ciceronianism'],
#              'eefhhiiopssuw': ['housewifeship'],
#              'aaceeelmn': ['lemnaceae'],
#              'efikloprstt': ['spittlefork'],
#              'addegho': ['doghead', 'godhead'],
#              'efiiinorrty': ['inferiority'],
#              'aaimns': ['samani', 'samian'],
#              'ceeegnnrt': ['centgener'],
#              'acehiortz': ['rhotacize'],
#              'cehiilnotx': ['xenolithic'],
#              'ceilptu': ['piculet'],
#              'cdehiinoort': ['cetorhinoid'],
#              'aaccegiilooptt': ['galactopoietic'],
#              'aeimmnrttu': ['manumitter'],
#              'aefgimnry': ['germanify', 'remagnify'],
#              'dderu': ['udder'],
#              'aaillmssv': ['alvissmal'],
#              'abeilrttu': ['tribulate'],
#              'agno': ['agon', 'ango', 'gaon', 'goan', 'gona'],
#              'norst': ['snort'],
#              'beeiinott': ['benitoite'],
#              'aailsty': ['talisay'],
#              'aaciilppst': ['papalistic', 'papistical'],
#              'bdegnorrruy': ['groundberry'],
#              'acdegiipr': ['pedigraic'],
#              'adegips': ['pegasid'],
#              'aloop': ['paolo'],
#              'eeemrt': ['meeter', 'remeet', 'teemer'],
#              'ers': ['ers', 'ser'],
#              'eiijknrt': ['jirkinet'],
#              'aeghilmort': ['lithomarge'],
#              'eiiiktw': ['wiikite'],
#              'aceehlmnostuy': ['enchylematous'],
#              'beiilsstttuuvy': ['substitutively'],
#              'aabiiilrtvy': ['variability'],
#              'cgloooprty': ['proctology'],
#              'chhimoottyy': ['ichthyotomy'],
#              'aaceehhilnnpssst': ['splanchnesthesia'],
#              'eegillnpsy': ['sleepingly'],
#              'hrttuy': ['truthy'],
#              'aacpx': ['capax'],
#              'acimnru': ['cranium'],
#              'ehillnpy': ['phylline'],
#              'deflorstuw': ['studflower'],
#              'cceeinopss': ['conspecies'],
#              'aceghilmrtu': ['multicharge'],
#              'aaabcdeirs': ['scarabaeid'],
#              'adilnrsy': ['islandry'],
#              'aceilnruvz': ['vulcanizer'],
#              'eijllor': ['jollier'],
#              'acdeemopstty': ['stapedectomy'],
#              'cegiinostz': ['gnosticize'],
#              'ccilottyy': ['cytolytic'],
#              'abimprrsuy': ['subprimary'],
#              'eoortz': ['zooter'],
#              'abehorst': ['bathorse'],
#              'abceillnnouu': ['uninoculable'],
#              'egilnnrsuvwy': ['unswervingly'],
#              'aeelnt': ['elanet', 'lanete', 'lateen'],
#              'ceenoorssstuu': ['courteousness'],
#              'eeloprstuuv': ['supervolute'],
#              'aacdjoorttu': ['coadjutator'],
#              'aceeimnoprrt': ['intercompare'],
#              'deeiilrssv': ['silverside'],
#              'eelnotvv': ['evolvent'],
#              'adinnortu': ['inundator'],
#              'aadeglnst': ['stageland'],
#              'aeefiiiilmnnnssst': ['infinitesimalness'],
#              'aabbcos': ['babasco'],
#              'aceeiklmr': ['creamlike'],
#              'aabiiillmppty': ['impalpability'],
#              'almo': ['loam', 'loma', 'malo', 'mola', 'olam'],
#              'aacdflnr': ['flancard'],
#              'acceenox': ['cacoxene'],
#              'aabeirsv': ['abrasive'],
#              'aaciilnpt': ['ancipital'],
#              'aaeemrt': ['amreeta'],
#              'ciioqtux': ['quixotic'],
#              'addeer': ['deader'],
#              'aaccinotty': ['cyanocitta'],
#              'eegilnnrssst': ['sterlingness'],
#              'efiiklloss': ['fossillike'],
#              'aceehmrs': ['cashmere'],
#              'aafhlmn': ['halfman'],
#              'adeooptx': ['taxeopod'],
#              'eeoorssttuu': ['osteosuture'],
#              'aeeghilnnrtty': ['threateningly'],
#              'aeinptty': ['antitype'],
#              'eefgoorr': ['foregoer'],
#              'ijkns': ['jinks'],
#              'abnoossu': ['absonous'],
#              'aeiiilnnnottty': ['intentionality'],
#              'adehiinooprtxy': ['hyperoxidation'],
#              'aeeilmrst': ['misrelate', 'salimeter'],
#              'chhiosstt': ['schottish'],
#              'bddeeirs': ['birdseed', 'seedbird'],
#              'abeiilnntuv': ['unibivalent'],
#              'deeeffiinnrrt': ['reindifferent'],
#              'giinntu': ['uniting'],
#              'achilmorss': ['scholarism'],
#              'beeehns': ['benshee', 'shebeen'],
#              'eemmoorst': ['merostome', 'osmometer'],
#              'cciloruu': ['curculio'],
#              'aadimmnoor': ['dromomania'],
#              'ddeeeeilmmnorst': ['intermeddlesome'],
#              'aakprwy': ['parkway'],
#              'aahinosttx': ['anthotaxis'],
#              'binnooostu': ['binotonous'],
#              'agilopr': ['poligar'],
#              'aeiimmnr': ['miriamne'],
#              'acdefioprt': ['forcipated'],
#              'ciinnnnoorsttu': ['noninstruction'],
#              'biopsy': ['biopsy'],
#              'accdehhmnnory': ['chondrenchyma'],
#              'acimnoor': ['acromion'],
#              'aabilrtuu': ['tubularia'],
#              'acellmmnoooru': ['monomolecular'],
#              'aabeltux': ['tableaux'],
#              'eellrssstu': ['lusterless', 'lustreless', 'resultless'],
#              'aabehhlloppprrstyy': ['blepharophryplasty'],
#              'aacceet': ['cetacea'],
#              'addinoorsy': ['dorsodynia'],
#              'ceiimmnnot': ['nonmimetic'],
#              'begiillnrsty': ['blisteringly'],
#              'eehinosst': ['hessonite'],
#              'ahmnoprty': ['phantomry'],
#              'eeegiimnrrsst': ['meistersinger'],
#              'acefilnno': ['falconine'],
#              'abcdeilnorsy': ['considerably'],
#              'aaeiillnortty': ['relationality'],
#              'chiilnopsuv': ['sulphovinic'],
#              'eeiorrtv': ['overtire'],
#              'abcimst': ['cambist'],
#              'acdeissty': ['ecdysiast'],
#              'aaaachilmnpstt': ['phantasmatical'],
#              'bbehlor': ['hobbler'],
#              'aeeklpss': ['peakless'],
#              'adeimnnos': ['mansioned'],
#              'cdeimoosty': ['dictyosome'],
#              'bdgiinn': ['binding'],
#              'ceennnooprssu': ['pronounceness'],
#              'aceegmort': ['categorem'],
#              'aekllmruwy': ['lukewarmly'],
#              'cgilooorsu': ['coglorious'],
#              'acdddeeiimnooorty': ['merycoidodontidae'],
#              'hlloppry': ['prophyll'],
#              'acceelnpr': ['precancel'],
#              'cdeeilmnopt': ['incompleted'],
#              ...})

# %%
def anagram_fast(myword):
    return words_bysig[signature(myword)]

# %%
anagram_fast('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
 anagrams_all = {word: anagram_fast(word) for word in wordclean if len(anagram_fast(word)) > 1}

# %%
len(anagrams_all)
# Out:
# 32890

# %%
# %timeit anagrams_all = {word: anagram_fast(word) for word in wordclean if len(anagram_fast(word)) > 1}
# Out:
# 1 loop, best of 3: 455 ms per loop
