# %%
word = open('words','r')

# %%
word
# Out:
# <_io.TextIOWrapper name='words' mode='r' encoding='UTF-8'>

# %%
wordlist = word.readlines()

# %%
wordlist[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
len(wordlist)
# Out:
# 235886

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron'.lower()
# Out:
# 'aaron'

# %%
wordclean = [word.strip().lower() for word in wordlist]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordunique = list(set(wordclean))

# %%
wordunique
# Out:
# ['nasalism',
#  'anaematosis',
#  'bloodguiltless',
#  'overdiffusely',
#  'tautomeral',
#  'weirdsome',
#  'algetic',
#  'quaedam',
#  'bahutu',
#  'walt',
#  'coddler',
#  'acrogamy',
#  'snoeking',
#  'congenerous',
#  'susurrant',
#  'elaphurine',
#  'luckful',
#  'admeasure',
#  'suberize',
#  'utilitarianism',
#  'poecilogony',
#  'resultancy',
#  'badlands',
#  'desucration',
#  'nattered',
#  'overwhipped',
#  'blackly',
#  'cellarer',
#  'nukuhivan',
#  'pyramidellidae',
#  'tilde',
#  'fencelet',
#  'labyrinthodonta',
#  'mannishness',
#  'neuroplasm',
#  'kneecap',
#  'presynaptic',
#  'sermonize',
#  'transvert',
#  'triform',
#  'germanic',
#  'ephelcystic',
#  'offscour',
#  'unvitalized',
#  'respan',
#  'cardlike',
#  'retie',
#  'trousering',
#  'sog',
#  'misrepeat',
#  'turbulentness',
#  'marxism',
#  'acetylic',
#  'septerium',
#  'kestrel',
#  'lakish',
#  'entrepot',
#  'gaintwist',
#  'steganopodous',
#  'mahdi',
#  'pseudoholoptic',
#  'algometry',
#  'strigiles',
#  'chimakuan',
#  'phaeton',
#  'howdie',
#  'diploma',
#  'drapable',
#  'codenization',
#  'ethnical',
#  'trinitration',
#  'thither',
#  'sackmaker',
#  'sublunar',
#  'grinch',
#  'tegument',
#  'uncondemnable',
#  'unaccursed',
#  'compete',
#  'regrind',
#  'thalassic',
#  'thyrsus',
#  'redsear',
#  'stela',
#  'societarianism',
#  'infrangibility',
#  'prickseam',
#  'multiloquy',
#  'graminivore',
#  'harefooted',
#  'balanophore',
#  'bleeding',
#  'rightlessness',
#  'russomaniac',
#  'congresswoman',
#  'infortunate',
#  'ormolu',
#  'each',
#  'fordable',
#  'hydrophanous',
#  'melancholious',
#  'prehumor',
#  'graphomotor',
#  'iliospinal',
#  'relievo',
#  'volency',
#  'appetize',
#  'manioc',
#  'perdicine',
#  'reincorporation',
#  'roadwise',
#  'rytina',
#  'oxyhalide',
#  'auriculariales',
#  'hyperpure',
#  'effeminatize',
#  'hostelry',
#  'lumbrical',
#  'bellyfish',
#  'indrawn',
#  'minutiously',
#  'androginous',
#  'historicophysical',
#  'vitrean',
#  'agrostography',
#  'staver',
#  'mantology',
#  'inveigher',
#  'cristina',
#  'plectopterous',
#  'arceuthobium',
#  'plurifacial',
#  'helpless',
#  'trying',
#  'resazurin',
#  'sant',
#  'seaberry',
#  'hexahedron',
#  'cytostromatic',
#  'ortiga',
#  'sealflower',
#  'anosmia',
#  'casually',
#  'misplacement',
#  'yohimbe',
#  'overtest',
#  'monovular',
#  'bhaiachari',
#  'superannuate',
#  'legalistically',
#  'freakish',
#  'desistance',
#  'gynecoid',
#  'uncompanied',
#  'unrallied',
#  'tourniquet',
#  'thumbtack',
#  'nosologist',
#  'boarcite',
#  'somnolency',
#  'representational',
#  'unbuying',
#  'circularwise',
#  'extramundane',
#  'sinarquism',
#  'undiffident',
#  'recollectable',
#  'previgilant',
#  'stomachful',
#  'strafer',
#  'whipcraft',
#  'potentialize',
#  'coadjuvancy',
#  'notopteroid',
#  'triplegia',
#  'druidess',
#  'discretively',
#  'wanghee',
#  'shalako',
#  'bannered',
#  'amusive',
#  'crested',
#  'hydropical',
#  'impoliticness',
#  'phalangean',
#  'reteach',
#  'subdeaconate',
#  'epigone',
#  'unnonsensical',
#  'pressfat',
#  'effectuate',
#  'diapsid',
#  'mesopodiale',
#  'quaggy',
#  'utriculariaceae',
#  'ewery',
#  'goyetian',
#  'unliveably',
#  'chiapanec',
#  'unerringness',
#  'flueless',
#  'inadvertence',
#  'waterworker',
#  'pantagruel',
#  'garageman',
#  'operabily',
#  'jutting',
#  'connach',
#  'tramway',
#  'mothlike',
#  'hurrah',
#  't',
#  'catamiting',
#  'hypabyssal',
#  'batocrinus',
#  'bregma',
#  'replotter',
#  'dive',
#  'unleashed',
#  'overstifle',
#  'overfluently',
#  'lophiidae',
#  'egotistical',
#  'osteoblastic',
#  'archegonium',
#  'sponsional',
#  'stassfurtite',
#  'corder',
#  'roadability',
#  'contact',
#  'depeople',
#  'paratherian',
#  'pseudolabium',
#  'bucolically',
#  'australene',
#  'hypochlorite',
#  'trochometer',
#  'sinecurist',
#  'tottery',
#  'hiller',
#  'postcoxal',
#  'understress',
#  'noncarbonate',
#  'araucan',
#  'nonround',
#  'speculatist',
#  'sexipolar',
#  'intercardinal',
#  'chlorocalcite',
#  'krobylos',
#  'monogynic',
#  'apetalae',
#  'raceway',
#  'sullenness',
#  'isopag',
#  'enhypostatic',
#  'ammocoetes',
#  'delsartian',
#  'overdubbed',
#  'gradgrindism',
#  'refrustrate',
#  'unshifted',
#  'delight',
#  'voet',
#  'panspermism',
#  'nympholept',
#  'restatement',
#  'crowberry',
#  'gyroscopics',
#  'mozarabic',
#  'write',
#  'aluminotype',
#  'biangulous',
#  'heinously',
#  'overfile',
#  'manship',
#  'yurok',
#  'leucolytic',
#  'decenyl',
#  'univalvular',
#  'overtower',
#  'darning',
#  'iliotrochanteric',
#  'penster',
#  'antispirochetic',
#  'cubitoplantar',
#  'diphosphothiamine',
#  'mesodesma',
#  'dingmaul',
#  'cartman',
#  'stickler',
#  'backfill',
#  'colymbus',
#  'waac',
#  'unsounded',
#  'lithophyl',
#  'writh',
#  'versus',
#  'peritrichously',
#  'mylodon',
#  'heyday',
#  'pectinic',
#  'nonpreservation',
#  'extraepiphyseal',
#  'gilo',
#  'dentinoid',
#  'periconchal',
#  'orpheum',
#  'nabber',
#  'trichorrhexic',
#  'bejazz',
#  'bogland',
#  'oroide',
#  'stereoplanula',
#  'siliciophite',
#  'amoebaea',
#  'constitutionalism',
#  'ignipotent',
#  'tortricidae',
#  'morigeration',
#  'undilatory',
#  'hallucination',
#  'undignifiedness',
#  'melamine',
#  'mayonnaise',
#  'heinous',
#  'fovea',
#  'acataphasia',
#  'lens',
#  'ductule',
#  'fadable',
#  'ressaut',
#  'foremarch',
#  'kvinter',
#  'tipsy',
#  'auganite',
#  'unchangeful',
#  'cystocolostomy',
#  'ventricumbent',
#  'kailyarder',
#  'volvocaceae',
#  'gekkonid',
#  'acalycine',
#  'cowslip',
#  'codding',
#  'linguadental',
#  'nonspecification',
#  'glaucodot',
#  'marquis',
#  'ipsedixitist',
#  'tachycardia',
#  'kinkaider',
#  'oracularness',
#  'ingaevones',
#  'cochliodus',
#  'helotry',
#  'wagering',
#  'bagnio',
#  'mycoplasmic',
#  'impanate',
#  'mopan',
#  'paula',
#  'hesitantly',
#  'humaneness',
#  'circumagitate',
#  'lurid',
#  'milligram',
#  'reef',
#  'tripaleolate',
#  'archmonarch',
#  'reintroduction',
#  'sail',
#  'pronomination',
#  'align',
#  'communicability',
#  'triolcous',
#  'holocephalan',
#  'ungreased',
#  'capriccio',
#  'bum',
#  'unseveredly',
#  'creaky',
#  'definitor',
#  'tetradite',
#  'sentimentalism',
#  'blockheadedness',
#  'polyphote',
#  'bodgery',
#  'zoons',
#  'commissaryship',
#  'subclavicular',
#  'saxifrax',
#  'xinca',
#  'fibromyectomy',
#  'haemorrhoid',
#  'hederaceous',
#  'tengere',
#  'barbary',
#  'praxean',
#  'uncomparable',
#  'antirailwayist',
#  'flotsam',
#  'rationalisticism',
#  'trilliaceae',
#  'fittingness',
#  'gerald',
#  'monogenism',
#  'unintentionality',
#  'mincopie',
#  'incomprehension',
#  'mainpast',
#  'grabber',
#  'microweber',
#  'colonnade',
#  'outlung',
#  'unconvincibility',
#  'uncharmable',
#  'axile',
#  'heliotaxis',
#  'stomatologic',
#  'putridly',
#  'flattening',
#  'limpsy',
#  'welcomely',
#  'paludicole',
#  'iatraliptic',
#  'ptyxis',
#  'choleic',
#  'lanky',
#  'overincurious',
#  'stingless',
#  'scrieve',
#  'ambassador',
#  'petrarchistic',
#  'protoleukocyte',
#  'provisor',
#  'funereal',
#  'unweighty',
#  'lingel',
#  'repercussiveness',
#  'halimeda',
#  'quassiin',
#  'dissonous',
#  'expatiatory',
#  'hircocervus',
#  'epicyclical',
#  'orchiditis',
#  'somethingness',
#  'prosily',
#  'haunter',
#  'infraorbital',
#  'aylet',
#  'kadikane',
#  'levigation',
#  'twinelike',
#  'aspidiotus',
#  'counterlode',
#  'institutress',
#  'jazyges',
#  'pillageable',
#  'slushy',
#  'embryonate',
#  'clad',
#  'adipometer',
#  'plasmoma',
#  'unabsorbed',
#  'jackass',
#  'tautirite',
#  'reptiliary',
#  'starchness',
#  'starchedly',
#  'halfheaded',
#  'verve',
#  'tetrasymmetry',
#  'crannage',
#  'birdland',
#  'modern',
#  'retarder',
#  'noncarnivorous',
#  'aldohexose',
#  'deflationary',
#  'griffithite',
#  'germanomaniac',
#  'cascabel',
#  'erethizontidae',
#  'azoxine',
#  'quintal',
#  'paroophoron',
#  'symbranchous',
#  'welterweight',
#  'uncourted',
#  'poristical',
#  'restis',
#  'iatrotechnics',
#  'subglumaceous',
#  'pseudoblepsis',
#  'errableness',
#  'vouge',
#  'consol',
#  'bisley',
#  'unarchitectural',
#  'unchangeably',
#  'burry',
#  'varletto',
#  'randell',
#  'backstretch',
#  'elevatory',
#  'histoblast',
#  'cyclocoelous',
#  'impolicy',
#  'axled',
#  'mistutor',
#  'rappage',
#  'goatsucker',
#  'arthrotomy',
#  'disrelated',
#  'unreverent',
#  'sandiferous',
#  'unadverse',
#  'craftsman',
#  'smallholder',
#  'quadrinomical',
#  'tuberculoma',
#  'guttiferales',
#  'sadistic',
#  'thunor',
#  'formalization',
#  'pipeful',
#  'weening',
#  'carapacic',
#  'bastardly',
#  'subsensation',
#  'sora',
#  'amphidiploid',
#  'waterstead',
#  'hymnologic',
#  'khet',
#  'tronc',
#  'mirth',
#  'undersphere',
#  'tallow',
#  'whussle',
#  'rangifer',
#  'neisseria',
#  'proamnion',
#  'jackfish',
#  'outtop',
#  'prerepresent',
#  'perenniality',
#  'fingerstall',
#  'missionary',
#  'esophagectasia',
#  'quid',
#  'intergranular',
#  'delusory',
#  'externation',
#  'nosepiece',
#  'neoarsphenamine',
#  'siderolite',
#  'tormentress',
#  'homodyne',
#  'enteropexy',
#  'unconsoled',
#  'sneezeproof',
#  'incorporealize',
#  'seminate',
#  'anemotaxis',
#  'ischuria',
#  'gemmae',
#  'myotic',
#  'resentless',
#  'balantidiosis',
#  'porismatic',
#  'scrutator',
#  'fucinita',
#  'murex',
#  'draggletailedly',
#  'negligibly',
#  'carload',
#  'chlamydoselachus',
#  'kanthan',
#  'endamebic',
#  'circus',
#  'planorotund',
#  'deep',
#  'denigrate',
#  'unostentatiously',
#  'cystignathine',
#  'seepweed',
#  'waddly',
#  'gnathonize',
#  'shellblowing',
#  'lumination',
#  'proautomobile',
#  'thestreen',
#  'sappho',
#  'misease',
#  'countersynod',
#  'nonabsorbable',
#  'untap',
#  'charon',
#  'potpie',
#  'sporozoite',
#  'foolishness',
#  'retractible',
#  'cephalon',
#  'dite',
#  'alternant',
#  'sulphurea',
#  'sesquiquartal',
#  'jimmy',
#  'phizog',
#  'binominal',
#  'spanner',
#  'unworld',
#  'creamfruit',
#  'toplike',
#  'cyathozooid',
#  'proofing',
#  'merenchymatous',
#  'prelease',
#  'grihastha',
#  'cladoselachea',
#  'enemyship',
#  'parorexia',
#  'provedly',
#  'angiectasis',
#  'helobious',
#  'scaphitidae',
#  'altared',
#  'calycoideous',
#  'smouser',
#  'baxter',
#  'defraudment',
#  'subcouncil',
#  'effodientia',
#  'astream',
#  'exporter',
#  'superaggravation',
#  'prothonotariat',
#  'unexhaustedly',
#  'rhexis',
#  'dapedius',
#  'kissy',
#  'semipinacolic',
#  'raff',
#  'cerianthidae',
#  'diabetogenic',
#  'inaesthetic',
#  'licit',
#  'stringer',
#  'automaton',
#  'redact',
#  'lathing',
#  'diver',
#  'indirected',
#  'sphincterismus',
#  'synodically',
#  'synthetism',
#  'overswim',
#  'protomammal',
#  'pargana',
#  'intersession',
#  'microgaster',
#  'bakal',
#  'extramodal',
#  'nonexamination',
#  'overpromise',
#  'planulan',
#  'preaching',
#  'vaunter',
#  'aristotelism',
#  'alkylogen',
#  'effulgence',
#  'rich',
#  'unrecognizable',
#  'arctalia',
#  'ostentation',
#  'undertruck',
#  'enlistment',
#  'eremology',
#  'nasality',
#  'asymptotically',
#  'skunkhead',
#  'pyelograph',
#  'harpress',
#  'stonelessness',
#  'autumnity',
#  'ergal',
#  'fellahin',
#  'chondrogen',
#  'sinfonietta',
#  'tampon',
#  'afteract',
#  'wiseweed',
#  'insessor',
#  'wisehead',
#  'geranyl',
#  'cremocarp',
#  'glaciaria',
#  'emulsion',
#  'penfieldite',
#  'pythagorism',
#  'warworn',
#  'bougar',
#  'zygomaticofacial',
#  'androecium',
#  'trustwoman',
#  'thrombolymphangitis',
#  'aeciostage',
#  'dentile',
#  'factable',
#  'hypermetaphorical',
#  'nimbused',
#  'unrazed',
#  'capitalist',
#  'humbugability',
#  'aphrodite',
#  'leery',
#  'fatigue',
#  'misspelling',
#  'subaud',
#  'introductor',
#  'hermitism',
#  'triodontophorus',
#  'cristi',
#  'tulkepaia',
#  'tetanically',
#  'viking',
#  'nunciature',
#  'gastrosuccorrhea',
#  'praenominal',
#  'unavowable',
#  'pantingly',
#  'droughty',
#  'axifugal',
#  'considerately',
#  'podicipedidae',
#  'destructional',
#  'bluebeard',
#  'pyramidally',
#  'terraquean',
#  'dissonancy',
#  'gauchely',
#  'bumming',
#  'hobnailer',
#  'odontotrypy',
#  'housefly',
#  'sanguineobilious',
#  'downcastness',
#  'geordie',
#  'pregreet',
#  'altrose',
#  'unsensuousness',
#  'megacoulomb',
#  'prohibitor',
#  'martagon',
#  'supercalender',
#  'myosynizesis',
#  'stanniferous',
#  'encenter',
#  'sialogenous',
#  'flavoring',
#  'soleiform',
#  'stolenwise',
#  'wartyback',
#  'throwaway',
#  'urceolar',
#  'outbleed',
#  'turntail',
#  'synthetical',
#  'preclothe',
#  'unsolidness',
#  'salic',
#  'untried',
#  'cymoscope',
#  'overspecialize',
#  'ref',
#  'bushland',
#  'snowless',
#  'recusant',
#  'aiguille',
#  'cutaneously',
#  'linguatuline',
#  'artificially',
#  'pinninerved',
#  'kuskos',
#  'rostrulum',
#  'consiliary',
#  'unembarrassed',
#  'hech',
#  'heterolytic',
#  'unshell',
#  'azha',
#  'exegetics',
#  'wowserdom',
#  'scrivello',
#  'scabbiness',
#  'flasher',
#  'triennium',
#  'diplospondylic',
#  'resummon',
#  'messianize',
#  'unspelt',
#  'alarmed',
#  'overwalk',
#  'andhra',
#  'cyclostomidae',
#  'checkbird',
#  'semiparallel',
#  'unresolve',
#  'merchantish',
#  'unfructed',
#  'microcephalia',
#  'gradgrindian',
#  'abalienate',
#  'consumption',
#  'premedieval',
#  'symphyantherous',
#  'lollard',
#  'favous',
#  'ineri',
#  'midshipmanship',
#  'asseveration',
#  'mulch',
#  'obliger',
#  'retain',
#  'corylus',
#  'proudful',
#  'fumitory',
#  'vick',
#  'intermetacarpal',
#  'racketeering',
#  'biwa',
#  'nonbreeding',
#  'desilicification',
#  'ustarana',
#  'turnix',
#  'illegitimacy',
#  'lecidioid',
#  'comparison',
#  'pluckily',
#  'superfat',
#  'troostitic',
#  'fluer',
#  'underhive',
#  'demurral',
#  'prinker',
#  'asellate',
#  'mononuclear',
#  'mortiferous',
#  'tetracerus',
#  'vaudeville',
#  'lopolith',
#  'wavira',
#  'steeplelike',
#  'prolation',
#  'flub',
#  'pretheological',
#  'extraprostatic',
#  'trichostrongylus',
#  'smaragdine',
#  'reattract',
#  'peropod',
#  'toe',
#  'uniformize',
#  'debonnaire',
#  'ananthous',
#  'cool',
#  'yappish',
#  'castlelike',
#  'germination',
#  'tubipore',
#  'alloisomer',
#  'unrhyme',
#  'nacarat',
#  'mabel',
#  'cotylosacral',
#  'thonga',
#  'diguanide',
#  'jungleside',
#  'unqueened',
#  'virbius',
#  'palaung',
#  'anteprostatic',
#  'demiculverin',
#  'antipharmic',
#  'catananche',
#  'administrable',
#  'aspersed',
#  'inaptness',
#  'fairing',
#  'scharlachberger',
#  'erraticalness',
#  'encumbrance',
#  'cryptomonadina',
#  'celtologist',
#  'bushfighter',
#  'erava',
#  'superarseniate',
#  'salamo',
#  'ureterointestinal',
#  'cinura',
#  'verminer',
#  'antapoplectic',
#  'pukishness',
#  'repercept',
#  'openhandedness',
#  'assimilate',
#  'pastelist',
#  'unpiece',
#  'shammed',
#  'halfheartedly',
#  'archineuron',
#  'glassworking',
#  'demigardebras',
#  'poimenics',
#  'isoscope',
#  'westralianism',
#  'bigthatch',
#  'pageanted',
#  'goldwork',
#  'intracervical',
#  'phototropically',
#  'arcuated',
#  'boho',
#  'subepithelial',
#  'barleyhood',
#  'mischance',
#  'voodooism',
#  'zoomania',
#  'electromechanical',
#  'gravic',
#  'sensomobility',
#  'undine',
#  'latrine',
#  'nostocaceae',
#  'unuprightness',
#  'wickless',
#  'pleasing',
#  'pencilling',
#  'hobbling',
#  'caffeone',
#  'leucotic',
#  'cotoxo',
#  'unchatteled',
#  'quoilers',
#  'citraconate',
#  'mongolioid',
#  'groggy',
#  'amboina',
#  'antidrug',
#  'rookie',
#  'mirror',
#  'granter',
#  'martha',
#  'subiculum',
#  'sermuncle',
#  'auribromide',
#  'montessorian',
#  'ich',
#  'nudate',
#  'unbended',
#  'lalang',
#  'pryingly',
#  'reassurance',
#  'anoestrus',
#  'lighten',
#  'starchlike',
#  'gently',
#  'antirachitically',
#  'ungrammaticism',
#  'cabureiba',
#  'deathbed',
#  'lymantriidae',
#  'glycohemia',
#  'proliturgical',
#  'utterance',
#  'cosmological',
#  'floreted',
#  'kodaker',
#  'uncorruptibility',
#  'anfractuousness',
#  'arecolin',
#  'grammaticize',
#  'tetrameral',
#  'cotinus',
#  'unworked',
#  'prelation',
#  'entapophysial',
#  'decreation',
#  'visie',
#  'desoxyanisoin',
#  'blepharemphysema',
#  'subgenerical',
#  'superstruction',
#  'nidifugous',
#  'cannibalistic',
#  'fibropurulent',
#  'porkman',
#  ...]

# %%
wordunique.sort()

# %%
wordunique[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
wordclean = [word.strip().lower() for word in open('words','r')]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordclean = sorted(list(set([word.strip().lower() for word in open('words','r')])))

# %%
wordclean[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
sorted('lives')
# Out:
# ['e', 'i', 'l', 's', 'v']

# %%
sorted('lives') == sorted('elvis')
# Out:
# True

# %%
sorted('love') == sorted('hate')
# Out:
# False

# %%
def signature(word):
    return ''.join(sorted(word))

# %%
signature('lives')
# Out:
# 'eilsv'

# %%
'/'.join(['a','b','c'])
# Out:
# 'a/b/c'

# %%
def anagram(word):
    return [w for w in wordclean if signature(w) == signature(word)]

# %%
anagram('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
# %timeit anagram('dictionary')
# Out:
# 1 loop, best of 3: 674 ms per loop

# %%
words_bysig = {}

for word in wordclean:
    words_bysig[signature(word)].append(word)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-198314f94f4a> in <module>()
#       2
#       3 for word in wordclean:
# ----> 4     words_bysig[signature(word)].append(word)
#
# KeyError: 'a'

# %%
import collections

# %%
words_bysig = collections.defaultdict(list)

for word in wordclean:
    words_bysig[signature(word)].append(word)

# %%
words_bysig
# Out:
# defaultdict(list,
#             {'eeiinnnorsttt': ['introsentient'],
#              'aaeiilmmrst': ['immaterials', 'materialism'],
#              'aaccelpt': ['placcate'],
#              'efhiipsw': ['wifeship'],
#              'adeimnnpuw': ['unimpawned'],
#              'aacdghiilloppr': ['diplographical'],
#              'aeinnnnorstt': ['nontransient'],
#              'agiiorrrty': ['irrigatory'],
#              'ehiooprstt': ['orthoepist'],
#              'aabciqstuu': ['subaquatic'],
#              'aeimooprtt': ['epitomator'],
#              'eehiklnoy': ['honeylike'],
#              'acdfiiimoorr': ['formicarioid'],
#              'bcdeeeino': ['obedience'],
#              'acdeen': ['decane'],
#              'abdimnr': ['birdman', 'manbird'],
#              'acfiiinnnnooott': ['nonnotification'],
#              'noruw': ['unrow'],
#              'aacdelno': ['deaconal'],
#              'acdeilnory': ['corydaline'],
#              'acehmnrtt': ['ratchment'],
#              'bcdeeeilnnrssuu': ['unreducibleness'],
#              'cghu': ['chug'],
#              'bgintu': ['tubing'],
#              'aeghopprty': ['graphotype'],
#              'bginoot': ['booting'],
#              'eerrtv': ['revert'],
#              'aceefmnnoprru': ['unperformance'],
#              'beefinrss': ['briefness'],
#              'eehhiinoprsstt': ['enterophthisis'],
#              'chiooopprtt': ['phototropic'],
#              'aaceeltx': ['excalate'],
#              'ahnrtu': ['thunar'],
#              'aaeglntu': ['angulate', 'gaetulan'],
#              'ennost': ['sonnet', 'stonen', 'tenson'],
#              'aefiloppry': ['polypifera'],
#              'aaabcchilnrry': ['brachycranial'],
#              'eeffikprtu': ['kupfferite'],
#              'aaaenprttx': ['tetrapanax'],
#              'dilooptuw': ['tulipwood'],
#              'acceehinsw': ['chancewise'],
#              'acelnorv': ['novercal'],
#              'aeglnopry': ['gyroplane'],
#              'aeegiinnorrtt': ['reintegration'],
#              'acdeprs': ['scraped'],
#              'aaeimrsst': ['aramitess'],
#              'egillnnsuw': ['unswelling'],
#              'aaegiimnnrsw': ['wagnerianism'],
#              'accceehilmoprst': ['spectrochemical'],
#              'aaaccdehinrst': ['saccharinated'],
#              'abeefiillnrtuz': ['unfertilizable'],
#              'ccdllnooopssuyy': ['cyclospondylous'],
#              'ccelnooootuyz': ['leucocytozoon'],
#              'adeeioprsx': ['peroxidase'],
#              'aelqu': ['equal', 'quale', 'queal'],
#              'aacefhhlrtt': ['healthcraft'],
#              'cehimrtuy': ['eurythmic'],
#              'acdehmps': ['campshed'],
#              'eeeilmnrst': ['resilement'],
#              'efgilrtuu': ['fulgurite'],
#              'aemprr': ['prearm', 'ramper'],
#              'aabbcdrs': ['scabbard'],
#              'adgkoosz': ['gadzooks'],
#              'aillott': ['talitol'],
#              'aehhirrst': ['ratherish'],
#              'hilmnnpy': ['nymphlin'],
#              'acdeeiinnops': ['scenopinidae'],
#              'eeelssy': ['eyeless'],
#              'diorstt': ['distort'],
#              'acdeehiilnop': ['ophicleidean'],
#              'aabehlt': ['hatable'],
#              'aiiillmnsttu': ['illuminatist'],
#              'aaehnppty': ['hypapante'],
#              'aaeehrwy': ['hereaway'],
#              'elrstwy': ['sweltry'],
#              'abdehiilnpssu': ['dispunishable'],
#              'ceiopswy': ['copywise'],
#              'aabeelnrsst': ['ratableness'],
#              'hlnoooppsuy': ['polyphonous'],
#              'acceeeehilmnppt': ['metepencephalic'],
#              'aadiloorstv': ['vasodilator'],
#              'acdeiillmt': ['dimetallic'],
#              'beeggiorrt': ['broggerite'],
#              'ddeeilprssy': ['dispersedly'],
#              'aaccehiilrtu': ['aurichalcite'],
#              'bensux': ['subnex'],
#              'eeinnr': ['nerine'],
#              'aaccehimrrst': ['characterism'],
#              'ahlot': ['altho', 'lhota', 'loath'],
#              'adehnorvy': ['hydrovane'],
#              'acddhiimnoost': ['chiasmodontid'],
#              'ackprs': ['sprack'],
#              'aceimntu': ['neumatic'],
#              'deeery': ['redeye'],
#              'aaabbiinosttz': ['sabbatization'],
#              'deefinrstu': ['unresifted'],
#              'aacmoorsstu': ['sarcomatous'],
#              'adeiinnottv': ['venditation'],
#              'deeffiioprty': ['foretypified'],
#              'aaaceehnnprrt': ['paranthracene'],
#              'aceehiimrstt': ['hemiteratics'],
#              'aceeeghiiilmnnnopst': ['encephalomeningitis',
#               'meningoencephalitis'],
#              'addeeeinnqqttuu': ['quinquedentated'],
#              'ccehinoor': ['orecchion'],
#              'ooprstv': ['provost'],
#              'eelpsux': ['expulse'],
#              'aabdinnrt': ['trainband'],
#              'aabeilnntu': ['biannulate'],
#              'ceiklnnru': ['uncrinkle'],
#              'aaccehinnort': ['acocantherin'],
#              'bceeemmnorsssu': ['cumbersomeness'],
#              'aaaeilmnorrtx': ['extramorainal'],
#              'aaaijnoptvy': ['yajnopavita'],
#              'ahlmnoppry': ['pronymphal'],
#              'aacdeiillmnnnot': ['monactinellidan'],
#              'aadiiprsst': ['aspidistra'],
#              'cceeehlorty': ['heterocycle'],
#              'deeeeimrsst': ['disesteemer'],
#              'ahiiilnppp': ['philippian'],
#              'acddeiiosst': ['datiscoside'],
#              'abceeikrstw': ['bracketwise'],
#              'lmooopssuy': ['polysomous'],
#              'cehw': ['chew'],
#              'ainoossst': ['anostosis'],
#              'acefinn': ['finance'],
#              'cdeinprstu': ['undescript'],
#              'beghlnou': ['bunghole'],
#              'defginr': ['fringed'],
#              'aabderv': ['bravade'],
#              'aabcehkors': ['ahorseback'],
#              'eeiilnootuvz': ['evolutionize'],
#              'ceiilnoott': ['entoolitic'],
#              'egilnossss': ['glossiness'],
#              'ccehilmoorrt': ['chlorometric'],
#              'aeqruvy': ['quavery'],
#              'aeelty': ['eyalet'],
#              'aaeghhimop': ['hemophagia'],
#              'adgiiloopst': ['paidologist'],
#              'chilnruy': ['urchinly'],
#              'acdeghimopr': ['demographic'],
#              'abeeiiprsttt': ['bitriseptate'],
#              'abcceikklst': ['stickleback'],
#              'aaaccinnosv': ['casanovanic'],
#              'aeenprrtu': ['enrapture'],
#              'aeeflrtuy': ['featurely'],
#              'ceeehlry': ['leechery'],
#              'addeeoprrty': ['depredatory'],
#              'aegrruv': ['gravure', 'verruga'],
#              'fimmoprsu': ['spumiform'],
#              'abcdeeiilnnors': ['inconsiderable'],
#              'egiimnnrttu': ['unremitting'],
#              'ailnottv': ['volitant'],
#              'aaeflmstu': ['sulfamate'],
#              'aacchiilorst': ['trichoclasia'],
#              'abeeeflrz': ['freezable'],
#              'aaceefkmr': ['facemaker'],
#              'accdeiiilpt': ['epidictical'],
#              'cdeiimpu': ['decipium'],
#              'aceeglny': ['elegancy'],
#              'cdegiiilnopsstuu': ['pseudolinguistic'],
#              'aknpry': ['pranky'],
#              'abeiilnnprsu': ['uninspirable'],
#              'gmnoorw': ['morwong'],
#              'acceiiimrrsstt': ['criticasterism'],
#              'abdilmnouy': ['lumbodynia'],
#              'aabcegiikmnnt': ['cabinetmaking'],
#              'eelnnoqtuu': ['uneloquent'],
#              'efikrrs': ['frisker'],
#              'begtu': ['begut'],
#              'eeilmoprs': ['perilsome'],
#              'ilno': ['lino', 'lion', 'loin', 'noil'],
#              'aeiilmnoostt': ['emotionalist'],
#              'cehhiiillot': ['heliolithic'],
#              't': ['t'],
#              'aaacillmnoty': ['anatomically'],
#              'aeemnorrrtu': ['remunerator'],
#              'abceeilnoprrs': ['cerebrospinal'],
#              'egnorssss': ['grossness'],
#              'aachilnopry': ['paronychial'],
#              'acelmnrsstu': ['transmuscle'],
#              'aceegilnnnoss': ['congenialness'],
#              'eghorrsttu': ['troughster'],
#              'aafrrs': ['sarraf'],
#              'ceefiinopsttv': ['postinfective'],
#              'ghhiillnoopps': ['philosophling'],
#              'aeeiklr': ['earlike'],
#              'acdeiilnppuu': ['pipunculidae'],
#              'finorsuuu': ['unfurious'],
#              'aciinprst': ['spirantic'],
#              'bcdennoortu': ['counterbond'],
#              'aeeehimpprssuz': ['superemphasize'],
#              'aaeffiilmrtvy': ['affirmatively'],
#              'aaciimnoorrz': ['microzoarian'],
#              'aabcgimo': ['cambogia'],
#              'bginntu': ['bunting'],
#              'abhimnorstuu': ['southumbrian'],
#              'acgijnnootu': ['conjugation'],
#              'cddeikoors': ['crooksided'],
#              'aceeeklr': ['keracele'],
#              'acceeilmoprstu': ['proceleusmatic'],
#              'aaffoorw': ['foofaraw'],
#              'cdefflnoorsu': ['snuffcolored'],
#              'eeeknt': ['ektene', 'ketene'],
#              'abbeiorr': ['barbeiro'],
#              'eilooprrvx': ['overprolix'],
#              'acdiijlnnnnoostu': ['nondisjunctional'],
#              'abeefflrsu': ['sufferable'],
#              'aacdeiorrty': ['eradicatory'],
#              'beirrvyy': ['ivyberry'],
#              'adehhioppst': ['diphosphate', 'phosphatide'],
#              'bceiiiilnnorttvy': ['inconvertibility'],
#              'addeiinnoort': ['deordination'],
#              'aacehlrr': ['archearl'],
#              'aaeklmrst': ['saltmaker'],
#              'acehiilmosst': ['schistomelia'],
#              'cdeeimnrsu': ['mercedinus'],
#              'allnsuuuy': ['unusually'],
#              'cdeggijnnortuu': ['counterjudging'],
#              'aacceillmstu': ['miscalculate'],
#              'ilops': ['polis', 'spoil'],
#              'acceeghilnopsty': ['psychogenetical'],
#              'eeeginprr': ['peregrine'],
#              'ailr': ['aril', 'lair', 'lari', 'liar', 'lira', 'rail', 'rial'],
#              'aimnnoruv': ['mavournin'],
#              'aabciimnrs': ['sicambrian'],
#              'abcdiiiiillnpsty': ['disciplinability'],
#              'abhirs': ['barish', 'shibar'],
#              'acdeeoortv': ['overcoated'],
#              'abceehnorr': ['abhorrence'],
#              'aabcchilmoprsu': ['sulphocarbamic'],
#              'hinpsx': ['sphinx'],
#              'aadeilnrsu': ['unsalaried'],
#              'acceenpsstu': ['susceptance'],
#              'ansttu': ['tutsan'],
#              'acgppsuu': ['scuppaug'],
#              'aacghinoprty': ['actinography'],
#              'ddgiilmn': ['middling'],
#              'aadfgl': ['fagald'],
#              'cdehiioru': ['echiuroid'],
#              'adhrs': ['shard'],
#              'aaaciiiinosttz': ['asiaticization'],
#              'hhllmooopsuy': ['homophyllous'],
#              'aaccgjmnnoortu': ['macroconjugant'],
#              'aaiils': ['sialia'],
#              'aeenopst': ['peastone'],
#              'abdehntu': ['unbathed'],
#              'aaceeiinnnrrtt': ['tricentenarian'],
#              'adeeiklnnpt': ['pendantlike'],
#              'abdhlorw': ['blowhard'],
#              'acelpstu': ['scapulet'],
#              'aacegillmort': ['algometrical'],
#              'ehhmoooprrstu': ['theromorphous'],
#              'aceeehinnrt': ['enheritance'],
#              'ceghiinost': ['histogenic'],
#              'aeeeknorttt': ['tetraketone'],
#              'cdeeehimnprt': ['decipherment'],
#              'egittu': ['guttie'],
#              'elnostu': ['lentous', 'sultone'],
#              'aeiknopttty': ['teapottykin'],
#              'epsu': ['supe'],
#              'aceikmrv': ['maverick'],
#              'aceiinnost': ['anticosine'],
#              'acceilmny': ['cyclamine', 'macilency'],
#              'beghmo': ['begohm'],
#              'afgiilostu': ['flagitious'],
#              'cehinopu': ['euphonic'],
#              'abeioorsu': ['aerobious'],
#              'aefknorrv': ['overfrank'],
#              'cklloo': ['ollock'],
#              'dehiilnooortt': ['orthotolidine'],
#              'aceilnoopr': ['procoelian'],
#              'accloprrsuu': ['corpuscular'],
#              'bdeeilmno': ['belemnoid'],
#              'gilo': ['gilo', 'goli'],
#              'aekp': ['peak'],
#              'achnnoorssuy': ['asynchronous'],
#              'ailmoostu': ['aulostomi'],
#              'befiiimnorstuu': ['bituminiferous'],
#              'hmmoorsu': ['mushroom'],
#              'aabelmnostt': ['nematoblast'],
#              'aamy': ['maya'],
#              'eeeehimmooprtz': ['hemopiezometer'],
#              'aceeghiru': ['gaucherie'],
#              'aaacdehiilort': ['atelorachidia'],
#              'alloorsuvy': ['valorously'],
#              'acchhinnoppsstyy': ['psychopannychist'],
#              'aaaceghilmot': ['galactohemia'],
#              'aeeiklnorstt': ['tetraskelion'],
#              'aacmnorstuy': ['austromancy'],
#              'aabciiillppty': ['applicability'],
#              'aacdenoprtt': ['pedantocrat'],
#              'agiinoorrtv': ['invigorator'],
#              'acfilnsu': ['unfiscal'],
#              'ccdehnoorty': ['chondrocyte'],
#              'aacehimpy': ['pachyemia'],
#              'eeiiklnprrt': ['printerlike'],
#              'aeemnooorrtty': ['aerotonometry'],
#              'fgllnou': ['longful'],
#              'cceeghilnrsy': ['screechingly'],
#              'aabehiilmmopy': ['hemiamblyopia'],
#              'aceelmmnorstuy': ['commensurately'],
#              'aaddeellnrttuuy': ['unadulteratedly'],
#              'eenorst': ['enstore', 'estrone', 'storeen', 'tornese'],
#              'aaabdeelnnpsstu': ['unadaptableness'],
#              'aaeeegimnnrssttuv': ['argumentativeness'],
#              'efgiinru': ['figurine'],
#              'abeeemrrs': ['besmearer'],
#              'aammnrt': ['tramman'],
#              'aacehinnt': ['acanthine'],
#              'aaeehilnopprsty': ['interapophyseal'],
#              'eginnosuu': ['ingenuous', 'unigenous'],
#              'aaaaimnnp': ['panamaian'],
#              'aaddehrstw': ['deathwards'],
#              'aeehoprrtty': ['hyperotreta'],
#              'acgiiilnrtu': ['liturgician'],
#              'ghilooorst': ['horologist'],
#              'aaiilnrz': ['alizarin'],
#              'deehimorrssx': ['desmorrhexis'],
#              'aceegilmort': ['geometrical', 'glaciometer'],
#              'aaeeiklnpst': ['peasantlike'],
#              'beeefrtt': ['befetter'],
#              'aceehimortt': ['heteratomic', 'theorematic'],
#              'dfnnouu': ['unfound'],
#              'iorsttu': ['tourist'],
#              'eikklnoo': ['nooklike'],
#              'aaaachimmnopr': ['pharmacomania'],
#              'himoprww': ['whipworm'],
#              'acdeelos': ['adolesce'],
#              'aaeinoprsttt': ['antiprostate'],
#              'abeefiijlnssstu': ['justifiableness'],
#              'cceinnoptttu': ['cunctipotent'],
#              'aachinoprtt': ['antatrophic'],
#              'aacehimnoor': ['choreomania'],
#              'ceiimoopstt': ['postmeiotic'],
#              'eegnnoorrsuu': ['neurosurgeon'],
#              'cdiimnortuu': ['inductorium'],
#              'cinorrsttu': ['instructor'],
#              'aaacehlnp': ['acalephan', 'acephalan'],
#              'aaccdeiinortt': ['accreditation'],
#              'cehikos': ['koschei'],
#              'acceeginnorz': ['recognizance'],
#              'cdehiiistt': ['ditheistic'],
#              'aacdeiilnrtu': ['clairaudient'],
#              'aacemnnoprt': ['pantomancer'],
#              'adefimorstw': ['afterwisdom'],
#              'ahlmmooopty': ['omphalotomy'],
#              'accdeiilorss': ['cardielcosis'],
#              'deilmnoprsw': ['spindleworm'],
#              'aablntu': ['butanal'],
#              'dehnprtuu': ['upthunder'],
#              'hiimst': ['isthmi', 'timish'],
#              'deeiltuy': ['yuletide'],
#              'bddegin': ['bedding'],
#              'aeltv': ['valet'],
#              'abccehmory': ['brachycome'],
#              'aceegiilnnpt': ['palingenetic'],
#              'cdeeory': ['decoyer'],
#              'ceefhhnort': ['henceforth'],
#              'aeeflm': ['female'],
#              'deilmxy': ['mixedly'],
#              'adelnnprtu': ['underplant'],
#              'adefhinos': ['fashioned'],
#              'adgiilnnpsuy': ['undisplaying'],
#              'aacddeeehlnnnss': ['cleanhandedness'],
#              'eehlllpssy': ['helplessly'],
#              'bbeeeinru': ['burniebee'],
#              'emoos': ['moose'],
#              'aaaccdeeeii': ['aecidiaceae'],
#              'egilnssw': ['wingless'],
#              'aailmoprssyy': ['myoparalysis'],
#              'bcilmnoo': ['colombin'],
#              'cdhilooopsu': ['chilopodous'],
#              'eeelnnortu': ['teleneuron'],
#              'cgnnoosuy': ['gonyoncus'],
#              'aacchhimnops': ['coachmanship'],
#              'aaablmnrsuy': ['myrabalanus'],
#              'aaabfilrrssttt': ['slartibartfast'],
#              'eeelnsssssx': ['sexlessness'],
#              'aeilprst': ['epistlar', 'pilaster', 'plaister', 'priestal'],
#              'accciiilmnoprtu': ['circumplication'],
#              'aaceehnpy': ['hypnaceae'],
#              'abcceimort': ['bromacetic'],
#              'aadfhimnprst': ['draftmanship'],
#              'fgghiiinnt': ['infighting'],
#              'aabcgiillotuy': ['coagulability'],
#              'acillmorsuuy': ['miraculously'],
#              'fgilnnnoow': ['nonflowing'],
#              'aaccdeiipr': ['epicardiac'],
#              'beelllmuu': ['umbellule'],
#              'eeglnoty': ['telegony'],
#              'abeilmstu': ['sublimate'],
#              'aceeehlnoprrssss': ['reproachlessness'],
#              'acceilmnnopu': ['uncompliance'],
#              'aaeeeinnrsssttt': ['transessentiate'],
#              'cdeeinoprrtu': ['interproduce', 'prereduction'],
#              'ehnnopr': ['nephron'],
#              'aegmnno': ['agnomen'],
#              'emnnopuy': ['pneumony'],
#              'ddiiioo': ['oidioid'],
#              'aaccegillmopsy': ['megascopically'],
#              'cdnnoopty': ['pycnodont'],
#              'aaaceilmmnrsst': ['sacramentalism'],
#              'aegjln': ['jangle'],
#              'adiillm': ['milliad'],
#              'aaacnpt': ['catapan'],
#              'aehiinprstt': ['tertianship'],
#              'abeflooorrtu': ['fluoroborate'],
#              'aacll': ['calla'],
#              'aeilnotuuv': ['uniovulate'],
#              'fggiilnt': ['giftling'],
#              'eeegs': ['seege'],
#              'achnosttu': ['outsnatch'],
#              'agiinnnnost': ['nonstaining'],
#              'aadehnnorty': ['nonahydrate'],
#              'dfhimorry': ['hydriform'],
#              'acdiopsy': ['diascopy'],
#              'aaccdinr': ['cardanic'],
#              'ddegor': ['dodger'],
#              'aceenorstttu': ['countertaste'],
#              'eelopprrssty': ['propertyless'],
#              'cdeeimnorttu': ['inductometer'],
#              'aaeinqrrstuu': ['quaternarius'],
#              'aadeehqrrstu': ['headquarters'],
#              'cdehnot': ['notched'],
#              'acmooprstty': ['cryptostoma'],
#              'bhinoooprtt': ['trophobiont'],
#              'ahillloswwy': ['wallowishly'],
#              'adeiknpr': ['kidnaper'],
#              'aaeiilmopprtvxy': ['approximatively'],
#              'deelnorruuv': ['unoverruled'],
#              'eggly': ['leggy'],
#              'adeeelnopprrty': ['preponderately'],
#              'deefhnstu': ['dehnstufe'],
#              'aegnoooprssu': ['asporogenous'],
#              'aabceehilv': ['achievable'],
#              'abiiilnostu': ['antibilious'],
#              'acceist': ['ascetic', 'castice', 'siccate'],
#              'adehiiipt': ['tiphiidae'],
#              'diillnoop': ['pollinoid'],
#              'beeiiklnnsssuu': ['unbusinesslike'],
#              'gknoo': ['kongo', 'ngoko'],
#              'eeimqstu': ['mesquite'],
#              'aegiilmnstty': ['estimatingly'],
#              'aeghhmopy': ['hemophagy'],
#              'acimnnnooopttu': ['noncomputation'],
#              'eeennorst': ['sonneteer'],
#              'deeeginnprssss': ['depressingness'],
#              'fhilnoprsuuw': ['unworshipful'],
#              'lnooptyy': ['polytony'],
#              'beeghinrrt': ['brightener'],
#              'ddelopr': ['plodder', 'proddle'],
#              'aabdorx': ['broadax'],
#              'acdeehiimnnoou': ['ichneumonoidea'],
#              'bcehijpsstu': ['subjectship'],
#              'beenorsssuu': ['uberousness'],
#              'beimt': ['timbe'],
#              'aehkmmrty': ['mythmaker'],
#              'aeiilmsttuv': ['stimulative'],
#              'acdhillopryy': ['hydropically'],
#              'ahjnno': ['johann'],
#              'ddilnopsy': ['spondylid'],
#              'eegiilmoprrssvy': ['improgressively'],
#              'adllmoy': ['modally'],
#              'cinooprsst': ['crosspoint'],
#              'aacegghimnoprt': ['magnetographic'],
#              'ikkoos': ['sokoki'],
#              'aabcelllot': ['collatable'],
#              'abelnz': ['benzal'],
#              'aabdeillnpsuy': ['undisplayable'],
#              'cdeiillooz': ['colloidize'],
#              'ddeeeennpprt': ['predependent'],
#              'aabhinnuu': ['buninahua'],
#              'adfiiillnnu': ['nullifidian'],
#              'agiiinnrv': ['virginian'],
#              'acdeimnnr': ['cinderman'],
#              'acceilmnrru': ['circumrenal'],
#              'aceeiillprtvy': ['replicatively'],
#              'hknoou': ['unhook'],
#              'abdeeklnt': ['blanketed'],
#              'bceiorstty': ['obstetricy'],
#              'aaclorrrstu': ['crurotarsal'],
#              'deeilortuv': ['overdilute'],
#              'aaaccdeillnorttuu': ['caudatolenticular'],
#              'dddeiiio': ['diiodide'],
#              'aadeimrrtz': ['dramatizer'],
#              'aaillpp': ['papilla'],
#              'amruz': ['mazur', 'murza'],
#              'cceeiinrsvvy': ['reviviscency'],
#              'deehimnooprrtuy': ['hydroperitoneum'],
#              'eeglmooprrs': ['spermologer'],
#              'abcehlrt': ['albrecht'],
#              'aadeinnnprt': ['pentandrian'],
#              'celloruv': ['overcull'],
#              'denprsuuu': ['unpursued', 'unusurped'],
#              'aachiillnooorst': ['chorioallantois'],
#              'aceilno': ['coelian'],
#              'aehmmorrtw': ['hammerwort'],
#              'addeeeghnoorsst': ['goodheartedness'],
#              'acdhiimnors': ['disharmonic'],
#              'aiimnrst': ['marinist', 'mistrain'],
#              'bghoru': ['brough'],
#              'gilnsstuu': ['singultus'],
#              'adeeflnnrsstuu': ['fraudulentness'],
#              'ceeijloprt': ['projectile'],
#              'ceiilrrssttuu': ['sericulturist'],
#              'ceenorstty': ['enterocyst'],
#              'acghhinooopprtyz': ['photozincography'],
#              'adgmnoru': ['gourmand'],
#              'fglu': ['gulf'],
#              'aelrrtt': ['rattler'],
#              'eeegqsu': ['squeege'],
#              'aeemnno': ['anemone', 'monaene'],
#              'deep': ['deep', 'peed'],
#              'cccdhhiilooooprt': ['coccolithophorid'],
#              'acehilprstu': ['tricephalus'],
#              'aceeffhinnprs': ['affenpinscher'],
#              'achiiorttxy': ['rhyotaxitic'],
#              'aaacfillnty': ['fanatically'],
#              'aabkooz': ['bazooka'],
#              'acelppsu': ['supplace'],
#              'acdeinosttu': ['outdistance'],
#              'ffgiortu': ['fogfruit'],
#              'abijllntuy': ['jubilantly'],
#              'aeeffnrt': ['afferent'],
#              'aaccehiiiilmprrst': ['archimperialistic'],
#              'acehirrstt': ['charterist'],
#              'aaiilnnrtvy': ['invariantly'],
#              'ccdeeeinn': ['indecence'],
#              'aaahiilppr': ['paraphilia'],
#              'giiknnw': ['winking'],
#              'bdhiiilot': ['lithobiid'],
#              'agilmopstuu': ['galumptious'],
#              'aaddilrsstw': ['distalwards'],
#              'aiinqstu': ['aquinist'],
#              'aaachimooprt': ['achromatopia'],
#              'adinostt': ['donatist'],
#              'acdehnrtuw': ['underwatch'],
#              'acceehilmmnopprst': ['preaccomplishment'],
#              'aaelmnsu': ['maenalus'],
#              'abbcegilrs': ['scribblage'],
#              'acciillmooopst': ['cosmopolitical'],
#              'deikllnu': ['unkilled'],
#              'abchiin': ['bianchi'],
#              'cceissu': ['succise'],
#              'ammrsy': ['smarmy'],
#              'acceellor': ['clearcole'],
#              'cenoostuuv': ['uncovetous'],
#              'deemopprssu': ['pseudosperm'],
#              'aaeegilmorrst': ['lagerstroemia'],
#              'aeflprtu': ['prateful'],
#              'adeiimnrty': ['mydriatine'],
#              'aadeiiimnnoprrssttu': ['superadministration'],
#              'abefiiillrtty': ['filterability'],
#              'aacdhiilmoprstt': ['archdiplomatist'],
#              'abcceegiinort': ['bacteriogenic'],
#              'deirstu': ['studier'],
#              'cfhinsu': ['fuchsin'],
#              'ceikloprsu': ['pricklouse'],
#              'aeinrrst': ['restrain', 'strainer', 'transire'],
#              'cchhimoooprr': ['chromophoric'],
#              'ceikny': ['nickey'],
#              'ceeiilmrtuv': ['vermiculite'],
#              'aacdiss': ['cassida'],
#              'aaehiilloprty': ['hyaloliparite'],
#              'aaadvy': ['yadava'],
#              'eentux': ['exeunt'],
#              'abeeinnqstuyz': ['byzantinesque'],
#              'ddeoopsux': ['pseudodox'],
#              'aceiinoorrtyz': ['oryzorictinae'],
#              'abenor': ['borean'],
#              'aeeeijklpr': ['jailkeeper'],
#              'ceeelooprrtw': ['electropower'],
#              'aceehimnnptu': ['pentachenium'],
#              'acchiopssstty': ['psychostatics'],
#              'aabceeillnnsy': ['enneasyllabic'],
#              'abiiilnsttuuy': ['unsuitability'],
#              'aeeglnprs': ['respangle'],
#              'hmooptyy': ['homotypy'],
#              'abiilmprty': ['impartibly'],
#              'abegimnno': ['bemoaning'],
#              'cehilmoorst': ['schorlomite'],
#              'aaccilmnpsuy': ['scapulimancy'],
#              'hiko': ['kiho'],
#              'cginppu': ['cupping'],
#              'acehinnorru': ['archineuron'],
#              'aaeeikkmnortt': ['katakinetomer'],
#              'adegnnpu': ['unpanged'],
#              'egimnnoost': ['monogenist', 'nomogenist'],
#              'dfiilmoopu': ['filopodium'],
#              'abost': ['basto', 'boast', 'sabot'],
#              'abceefiiln': ['beneficial'],
#              'adeeiloopstu': ['petaloideous'],
#              'aeegorruv': ['overargue'],
#              'aaelltuvv': ['valvulate'],
#              'aceeggnortuu': ['countergauge'],
#              'fhiiorsty': ['historify'],
#              'aciiootttuxy': ['autotoxicity'],
#              'aaeikrt': ['karaite'],
#              'aeehlnopstu': ['elephantous'],
#              'acdiloorsty': ['dislocatory'],
#              'dehiimost': ['edomitish'],
#              'aacehnprrt': ['petrarchan'],
#              'iimnopssz': ['spinozism'],
#              'ceehiprr': ['cipherer'],
#              'aeglmotu': ['outgleam'],
#              'aggilnyz': ['gazingly'],
#              'eegr': ['gree'],
#              'aadeilruv': ['luvaridae'],
#              'abciillst': ['ballistic'],
#              'bcceeehkrrry': ['checkerberry'],
#              'acceeillnnort': ['nonelectrical'],
#              'eehmorrt': ['motherer'],
#              'aafillnrstuv': ['transfluvial'],
#              'aabceegiilnot': ['abiogenetical'],
#              'adknor': ['konrad'],
#              'bdellnossuy': ['boundlessly'],
#              'cdeeeiimprv': ['imperceived'],
#              'ceiilstuvxy': ['exclusivity'],
#              'aachiilnnopt': ['antiphonical'],
#              'bbggino': ['gobbing'],
#              'aeilmnorrz': ['normalizer'],
#              'jlsuu': ['julus'],
#              'adlnou': ['unload'],
#              'eeggnoy': ['geogeny'],
#              'aacdehmoorst': ['desmothoraca'],
#              'aaaccjo': ['cacajao'],
#              'ceennoqstu': ['consequent'],
#              'adeehijlopu': ['judaeophile'],
#              'bhiillnot': ['billionth'],
#              'eeinoppprrsssu': ['presuppression'],
#              'aabdelopt': ['adoptable'],
#              'adeeffnnorsst': ['affrontedness'],
#              'aghnooprstu': ['prognathous'],
#              'blnnouy': ['unnobly'],
#              'aacefiinprrsttt': ['antipriestcraft'],
#              'addeeimoprss': ['desperadoism'],
#              'aacinorstt': ['castration'],
#              'aaagghilnorrry': ['laryngorrhagia'],
#              'cdeeennnorsstuv': ['unconvertedness'],
#              'abeefilnprtuu': ['unputrefiable'],
#              'aceklnopst': ['alpenstock'],
#              'adeeiistv': ['daviesite'],
#              'abelmprsuy': ['presumably'],
#              'aadhinorr': ['arianrhod', 'hordarian'],
#              'adeeemnoprrstt': ['predemonstrate'],
#              'abdeiilmps': ['piebaldism'],
#              'aadeiilmnopsstt': ['postmediastinal'],
#              'bbehor': ['hobber'],
#              'nooswy': ['swoony'],
#              'abeehilnooprssst': ['blepharostenosis'],
#              'aghilot': ['goliath'],
#              'accdnooorrty': ['concordatory'],
#              'cchilt': ['clitch'],
#              'aaelmpty': ['playmate'],
#              'aeefilnoprrt': ['planoferrite'],
#              'aeiklnpsy': ['pansylike'],
#              'egnortu': ['tonguer'],
#              'acdhilmopssstyyy': ['dactylosymphysis'],
#              'aacdeeefns': ['defeasance'],
#              'beelnnnossu': ['unnobleness'],
#              'accehiinoorssuv': ['ischiocavernous'],
#              'abcehoprrstuy': ['brachypterous'],
#              'aacciilmnrsttu': ['circumstantial'],
#              'acmnory': ['acronym', 'romancy'],
#              'dgillnorsu': ['groundsill'],
#              'aabclrstty': ['abstractly'],
#              'aeehlnoprtt': ['tetraphenol'],
#              'beimorz': ['bromize'],
#              'ehiortvwwy': ['viewworthy'],
#              'adeeilmru': ['lemuridae'],
#              'ghsu': ['gush', 'shug', 'sugh'],
#              'eiimnrtx': ['intermix'],
#              'deiprrstu': ['disrupter'],
#              'aaaallmmy': ['malayalam'],
#              'deegiilprv': ['privileged'],
#              'cimmnooot': ['commotion'],
#              'abillorssuuy': ['salubriously'],
#              'aacdpru': ['crapaud'],
#              'adeeiilnsssuz': ['dissensualize'],
#              'ccdeeiimnooos': ['coenodioecism'],
#              'adiloprs': ['saprodil'],
#              'eeeinrss': ['eeriness'],
#              'aaiiklmprs': ['palikarism'],
#              'aaaefhillmort': ['thalamiflorae'],
#              'aabdeilnrssst': ['bastardliness'],
#              'degiinnnt': ['intending'],
#              'accdeiiinnnoorttuv': ['countervindication'],
#              'adhilsy': ['ladyish', 'shadily'],
#              'aceefhn': ['cafeneh'],
#              'aaaceeghlnooppry': ['paleoceanography'],
#              'eel': ['eel', 'lee'],
#              'aeeilnrsttx': ['externalist'],
#              'aaacddeiilqrrttuu': ['quadriarticulated'],
#              'aeeellsss': ['leaseless'],
#              'eehlnsssw': ['welshness'],
#              'ceeilmrtu': ['lucimeter'],
#              'chlmoopryy': ['polychromy'],
#              'beeorrsv': ['observer'],
#              'hhsu': ['hush'],
#              'aabbceiiikllmnoopt': ['bibliokleptomaniac'],
#              'acelpsy': ['cypsela'],
#              'aeilqstu': ['equalist'],
#              'aceosstu': ['seascout'],
#              'ghhitt': ['thight'],
#              'aceiilmoss': ['semisocial'],
#              'adeimnnort': ['antimodern', 'ordainment'],
#              'abchiinst': ['absinthic'],
#              'aeimnpprsst': ['panspermist'],
#              'deiiiimntuvz': ['diminutivize'],
#              'adeemnstuu': ['mansuetude'],
#              'aceilnors': ['censorial', 'sarcoline'],
#              'acdeeillmnoooo': ['aeolomelodicon'],
#              'accdeeinprsst': ['practicedness'],
#              'ceeginnrt': ['centering'],
#              'ccginnorru': ['concurring'],
#              'abchimnr': ['birchman'],
#              'aabbcos': ['babasco'],
#              'adeemnrrtt': ['retardment'],
#              'ginprsy': ['springy'],
#              'dehinrsuv': ['unshrived'],
#              'abefintuuy': ['unbeautify'],
#              'aeelmprrtuy': ['prematurely'],
#              'accceillnnorty': ['concentrically'],
#              'deeeimrsst': ['semidesert'],
#              'chmnnoo': ['mononch'],
#              'eeglorsssu': ['grouseless'],
#              'adeeginnopprrt': ['preponderating'],
#              'finort': ['forint', 'fortin'],
#              'achlst': ['slatch'],
#              'aacgillmnoorsty': ['gastronomically'],
#              'adegiinorsz': ['disorganize'],
#              'aeghhlmmopstu': ['megophthalmus'],
#              'bddgilor': ['goldbird'],
#              'beeirsstu': ['suberites'],
#              'abbiillorty': ['bibliolatry'],
#              'aadlnot': ['oatland'],
#              'aeegiinorrttv': ['interrogative'],
#              'aaaloqrstu': ['squatarola'],
#              'aeefilst': ['fetiales'],
#              'abdimrsy': ['darbyism'],
#              'addeggiillnooor': ['oligodendroglia'],
#              'aaceghlmnooprrsy': ['pharyngoscleroma'],
#              'acdhinnoosstu': ['disconanthous'],
#              'aaegimnnrt': ['argentamin'],
#              'beeilsttu': ['betulites'],
#              'aprrsy': ['sparry'],
#              'hiknottu': ['outthink'],
#              'aabceiprssuy': ['presbyacusia'],
#              'ablosttu': ['subtotal'],
#              'acghiioppx': ['xiphopagic'],
#              'aabbdllny': ['bandyball'],
#              'aceelmnnoooprstuy': ['contemporaneously'],
#              'adnrt': ['drant'],
#              'aacdimoorst': ['sarcomatoid'],
#              'deeoopprssu': ['pseudospore'],
#              'adimopssst': ['spasmodist'],
#              'adeknotw': ['downtake', 'takedown'],
#              'aclnnosttu': ['consultant'],
#              'eimnrsu': ['neurism', 'semiurn'],
#              'acdefiilnsu': ['fiducinales'],
#              'adeiiptt': ['pittidae'],
#              'aeinorst': ['arsonite',
#               'asterion',
#               'oestrian',
#               'rosinate',
#               'serotina'],
#              'aaaccehimnortu': ['centauromachia'],
#              'dhhmooprry': ['hydromorph'],
#              'cklmmoos': ['slommock'],
#              'cdemoy': ['comedy'],
#              'acddehillmoopsuy': ['diplochlamydeous'],
#              'giltu': ['guilt'],
#              'accdeeilnopy': ['encyclopedia'],
#              'adehimoopprsu': ['pseudomorphia'],
#              'acciiinnort': ['circination'],
#              'cchinort': ['triconch'],
#              'aefmorrrty': ['foremartyr'],
#              'accchhiinnoppsstyy': ['psychopannychistic'],
#              'aaadhrs': ['sharada'],
#              'acddilny': ['candidly'],
#              'aefgllnoss': ['flagonless'],
#              'aaccklp': ['calpack'],
#              'adefhiioprsstuy': ['hyperfastidious'],
#              'denortu': ['tendour', 'unroted'],
#              'abeennnorssstuv': ['unobservantness'],
#              'aachiloprssty': ['astrophysical'],
#              'bbcerrsu': ['scrubber'],
#              'aeeennorsstv': ['overneatness'],
#              'deist': ['deist', 'steid'],
#              'acceginoorrtt': ['gerontocratic'],
#              'aaiillnopt': ['palliation'],
#              'eeemmnoprtv': ['premovement'],
#              'ccenooory': ['cocoonery'],
#              'aacdehiiiinnorsttz': ['dechristianization'],
#              'abciouv': ['bivouac'],
#              'eefiinorrssu': ['resiniferous'],
#              'bdhlooot': ['hotblood'],
#              'aefhlr': ['halfer'],
#              'addeilmtty': ['admittedly'],
#              'acefiillnorstuuv': ['fluviolacustrine'],
#              'aaillmor': ['amarillo'],
#              'aeelmortt': ['altometer'],
#              'abehill': ['habille'],
#              'adgiinsst': ['angdistis'],
#              'acdllor': ['collard'],
#              'aellpru': ['pleural'],
#              'acdehlmoos': ['schooldame'],
#              'accdeehhiirt': ['trichechidae'],
#              'aelorssstuu': ['lestosaurus'],
#              'aacceilnu': ['lucinacea'],
#              'abbhiopst': ['abbotship'],
#              'hioppsw': ['woppish'],
#              'aeemrrtuy': ['ureametry'],
#              'ceiks': ['skice'],
#              'cekkloy': ['keylock'],
#              'chilnopsw': ['clownship'],
#              'aacdiilmnosy': ['isodynamical'],
#              'aceiosstw': ['coastwise'],
#              'aachllopry': ['polyarchal'],
#              'abdeintuy': ['butadiyne'],
#              'aceehiirstttx': ['extratheistic'],
#              'aaeilnnrttu': ['antineutral', 'triannulate'],
#              'deeeinnoprtt': ['predetention'],
#              'accceosstuuu': ['cuscutaceous'],
#              'aacehllnortu': ['lateronuchal'],
#              'ailorsst': ['solarist'],
#              'aaaceillloosv': ['alveoloclasia'],
#              'aceehlnptt': ['planchette'],
#              'esttuvy': ['vetusty'],
#              'ginprru': ['purring'],
#              'acinossy': ['cyanosis'],
#              'ceemmntu': ['cementum'],
#              'aaiilmnorst': ['rationalism'],
#              'eefllnortuvy': ['overfluently'],
#              'aachnnot': ['acanthon'],
#              'dmnooopy': ['monopody'],
#              'bellnosuu': ['unsoluble'],
#              'acilnoottt': ['cottontail'],
#              'aaalloppstty': ['palatoplasty'],
#              'cccelnsuuy': ['succulency'],
#              'bbbeinor': ['bobbiner'],
#              'ccdeipu': ['dicecup'],
#              'aeghipprr': ['perigraph'],
#              'effnoorrt': ['forefront'],
#              'aceehinprss': ['preachiness'],
#              'cdeiilmotuv': ['multivoiced'],
#              'ceeinoprrrsstuu': ['countersurprise'],
#              'cdeeimnu': ['mucedine'],
#              'deeeinprtux': ['expenditure'],
#              'aacehloprstt': ['posttracheal'],
#              'eoorttuv': ['outvoter'],
#              'accghinooprsy': ['psychoorganic'],
#              'aceilmnnopstu': ['complutensian'],
#              'aceghhimorr': ['hemorrhagic'],
#              'hhooopprssuy': ['physophorous'],
#              'deorrstw': ['wordster'],
#              'cclnoooorsu': ['concolorous'],
#              'deeorrstu': ['trousered'],
#              'accdeiinoortt': ['decortication'],
#              'aaegghllnooprssy': ['glossopharyngeal'],
#              'aacilstt': ['statical'],
#              'acceehhilrs': ['schleichera'],
#              'adeptu': ['update'],
#              'bdeeggnu': ['unbegged'],
#              'acgilnoosstt': ['sanctologist'],
#              'adelmnopr': ['polderman'],
#              'filmorsty': ['styliform'],
#              'acceffiinosuu': ['unefficacious'],
#              'aaeggiimnrrs': ['gregarianism'],
#              'aghilortu': ['roughtail'],
#              'aaeeiimmnpst': ['ampasimenite'],
#              'jnnoorru': ['nonjuror'],
#              'achhiopprstu': ['phosphaturic'],
#              'addllnorry': ['landlordry'],
#              'aeeglp': ['paegel', 'paegle', 'pelage'],
#              'bcdeeeiltt': ['detectible'],
#              'bfinow': ['bowfin'],
#              'aabceillmp': ['implacable'],
#              'abeiilmoprrsv': ['proverbialism'],
#              'aeehhlrsst': ['hearthless'],
#              'aeerrstv': ['traverse'],
#              'achhilooppsty': ['photophysical'],
#              'aciilnoptty': ['polytitanic'],
#              'aabehlmnsu': ['unshamable'],
#              'aaegimnpstt': ['pentagamist'],
#              'abdeiilnox': ['inoxidable'],
#              'dggilnos': ['lodgings'],
#              'agglnopw': ['plowgang'],
#              'ceehilstt': ['telestich'],
#              'aeelnnsssstw': ['wantlessness'],
#              'dilnowy': ['downily'],
#              'eeeeilnnoprssssssx': ['expressionlessness'],
#              'cdiilnstu': ['dulcinist'],
#              'achort': ['cathro', 'orchat'],
#              'ablmu': ['album'],
#              'cchhiioprtty': ['trichophytic'],
#              'eeefnnorz': ['nonfreeze'],
#              'acdeeiinnortv': ['revendication'],
#              'demmooossuy': ['mesomyodous'],
#              'aaenpp': ['papane'],
#              'hoop': ['hoop', 'phoo', 'pooh'],
#              'abdehnrrt': ['brandreth'],
#              'abcchiilmo': ['choliambic'],
#              'aeiilrtuz': ['ritualize', 'uralitize'],
#              'aabdilmno': ['abdominal'],
#              'aaaccghiilmnooooptt': ['anatomicopathologic',
#               'pathologicoanatomic'],
#              'bdiiinnru': ['indirubin'],
#              'aeeillorrttuu': ['aurotellurite'],
#              'bdeilnou': ['unboiled', 'unilobed'],
#              'abelorsv': ['absolver'],
#              'aacelnsstu': ['actualness'],
#              'abeeefkst': ['beefsteak'],
#              'cehopprttyy': ['cryptophyte'],
#              'adiilmnoootz': ['dolomization'],
#              'aabcehilmmnrs': ['malebranchism'],
#              'bcehiloorsu': ['herbicolous'],
#              'ahiinopttyz': ['typhization'],
#              'acdeilnopt': ['placentoid'],
#              'aabefklnnru': ['unfrankable'],
#              'acehilooprt': ['orthoepical'],
#              'acllpryy': ['caprylyl'],
#              'aacdefiqrrtuu': ['quadrifurcate'],
#              'aeeilmtz': ['metalize'],
#              'aaacdeiilmops': ['lasiocampidae'],
#              'errty': ['retry', 'terry'],
#              'abeoprrrttu': ['perturbator'],
#              'chint': ['chint', 'nitch'],
#              'cdeeenoortu': ['deuterocone'],
#              'adehoortt': ['deathroot'],
#              'acehiinnnrssstu': ['unchristianness'],
#              'acdehlrsu': ['schedular'],
#              'deeinprrst': ['rinderpest'],
#              'ceeilnqstu': ['liquescent'],
#              'eehimmrsu': ['hemimerus'],
#              'acehiiloprst': ['sphaerolitic'],
#              'adkopr': ['drokpa'],
#              'eeiloprst': ['epistoler', 'peristole', 'perseitol', 'pistoleer'],
#              'aahllp': ['pallah'],
#              'fnouxy': ['unfoxy'],
#              'nprsu': ['snurp', 'spurn'],
#              'egilrz': ['grizel'],
#              'aceeehmnnortv': ['carvomenthene'],
#              'cilmryy': ['myricyl'],
#              'effhilrw': ['whiffler'],
#              'aaeffggr': ['graffage'],
#              'bcdegiiknt': ['bedticking'],
#              'behillos': ['shoebill'],
#              'addeeintuv': ['denudative', 'undeviated'],
#              'aaeeintu': ['eutaenia'],
#              'abcceelors': ['cercolabes'],
#              'aahiklst': ['halakist'],
#              'abcilor': ['orbical'],
#              'bilooyz': ['boozily'],
#              'bddein': ['debind'],
#              'acdeeghnnnssu': ['unchangedness'],
#              'admqruu': ['quadrum'],
#              'aiknrssu': ['russniak'],
#              'aehiklrs': ['rashlike'],
#              'fghhiorrtt': ['forthright'],
#              'adeinps': ['ipseand', 'panside', 'pansied'],
#              'aceefiklnru': ['furnacelike'],
#              'giilmns': ['simling', 'smiling'],
#              'aiilopprt': ['propitial', 'triplopia'],
#              'aabciilmnns': ['cannibalism'],
#              'aaccehllnsty': ['cyclanthales'],
#              'deiikmnot': ['ketonimid'],
#              'cginnoorsuu': ['incongruous'],
#              'addeeiipss': ['diapedesis'],
#              'aiilmnorty': ['minatorily'],
#              'aeemortux': ['auxometer'],
#              'aehilmny': ['hymenial'],
#              'deinx': ['index'],
#              'aceeehilnopprrrt': ['peripherocentral'],
#              'aceinnnorstv': ['inconversant'],
#              'aaceegiiimnnnostt': ['antimiscegenation'],
#              'eeefmnprrt': ['preferment'],
#              'degiiiilopsttt': ['epiglottiditis'],
#              'bceeeilpprsstu': ['presusceptible'],
#              'cceeinooorrstt': ['corticosterone'],
#              'aaaaiilnnprst': ['antilapsarian'],
#              'aegilnrry': ['yarringle'],
#              'aeiinoooprsssuvvv': ['ovoviviparousness'],
#              'agtu': ['gaut'],
#              'aabdellnt': ['tableland'],
#              'eeeinst': ['steenie'],
#              'abcdiijrsuuy': ['subjudiciary'],
#              'addeeiiotvx': ['deoxidative'],
#              'aahnppty': ['panpathy'],
#              'aeeilntv': ['elvanite', 'lavenite'],
#              'giilnopt': ['piloting'],
#              'ehllooorvw': ['overhollow'],
#              'bcdeinor': ['bicorned'],
#              'bhsuy': ['bushy'],
#              'aaabceenr': ['abearance'],
#              'agilnpp': ['lapping'],
#              'ciinoorst': ['coronitis'],
#              'acemnprst': ['scarpment'],
#              'emop': ['mope', 'poem', 'pome'],
#              'aceeeginnooprstu': ['counterespionage'],
#              'cceehinooprrrty': ['hypercorrection'],
#              'addhims': ['maddish'],
#              'acilmnouy': ['alcyonium'],
#              'amux': ['maux'],
#              'adegiinost': ['diisatogen'],
#              ...})

# %%
def anagram_fast(word):
    return words_bysig[signature(word)]

# %%
anagram_fast('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
anagrams_all = {word: anagram_fast(word) for word in wordclean if len(anagram_fast(word)) > 1}

# %%
len(anagrams_all)
# Out:
# 32890

# %%
# %timeit anagrams_all = {word: anagram_fast(word) for word in wordclean if len(anagram_fast(word)) > 1}
# Out:
# 1 loop, best of 3: 453 ms per loop
