# %%
word = open('words','r')

# %%
word
# Out:
# <_io.TextIOWrapper name='words' mode='r' encoding='UTF-8'>

# %%
wordlist = word.readlines()

# %%
wordlist[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aaa\n',
#  'aah\n',
#  'aahed\n',
#  'aahing\n',
#  'aahs\n',
#  'aal\n',
#  'aalii\n']

# %%
len(wordlist)
# Out:
# 354938

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron'.lower()
# Out:
# 'aaron'

# %%
wordclean = [word.strip().lower() for word in wordlist]

# %%
wordclean[:10]
# Out:
# ['a', 'a', 'aa', 'aaa', 'aah', 'aahed', 'aahing', 'aahs', 'aal', 'aalii']

# %%
wordunique = list(set(wordclean))

# %%
wordunique
# Out:
# ['',
#  'pressuring',
#  'ghostship',
#  'zeugmas',
#  'bazaar',
#  'overcasual',
#  'medlar',
#  'cornflakes',
#  'reassessed',
#  'photoset',
#  'spall',
#  'scarph',
#  'laddock',
#  'afterend',
#  'unsmoulderingly',
#  'nonreception',
#  'intestinally',
#  'fossicks',
#  'itatartrate',
#  'misbeliever',
#  'dinamode',
#  'rosebushes',
#  'fanaticise',
#  'burds',
#  'cadet',
#  'clenches',
#  'eliminate',
#  'overpoise',
#  'programmatically',
#  'greenbul',
#  'kennedy',
#  'renn',
#  'kusso',
#  'hawcuaite',
#  'upsurges',
#  'saintlily',
#  'paregoric',
#  'carpetmaking',
#  'becrawling',
#  'tropologizing',
#  'enami',
#  'retinge',
#  'suovetaurilia',
#  'tensibleness',
#  'underprized',
#  'ashimmer',
#  'noex',
#  'army',
#  'unilaminar',
#  'sexlike',
#  'galactodensimeter',
#  'highlight',
#  'pleasureful',
#  'forwalk',
#  'overpress',
#  'anopisthograph',
#  'unsnug',
#  'palaeologist',
#  'nondoubting',
#  'outmatch',
#  'abiological',
#  'postrachitic',
#  'bibliopolically',
#  'improperly',
#  'subchannels',
#  'altiplanicie',
#  'eschatologist',
#  'veering',
#  'baetyl',
#  'cyrtoceracone',
#  'idant',
#  'nonexhausted',
#  'yeomen',
#  'infusibleness',
#  'tympanomandibular',
#  'forbearingness',
#  'typhoidal',
#  'nonreducibility',
#  'illnesses',
#  'dasein',
#  'advantageous',
#  'bipartisanship',
#  "comic's",
#  'unattainableness',
#  'alterably',
#  'vesicates',
#  'neighboress',
#  'seaweeds',
#  'minbar',
#  'oversentimentality',
#  'nidary',
#  'calthrop',
#  'pseudoreformatory',
#  'bonaci',
#  'supervisorship',
#  'crenature',
#  'pseudofamous',
#  'idiolect',
#  'curiet',
#  'elvish',
#  'monotellurite',
#  'symphily',
#  'overtenderly',
#  'woodsmen',
#  'bladdernut',
#  'cleaves',
#  'repile',
#  'sternocoracoid',
#  'saltfat',
#  'untraceably',
#  'unprincipledness',
#  'scrapler',
#  'wince',
#  'salvational',
#  'glossarial',
#  'bulbar',
#  'salpid',
#  'perroquet',
#  'associators',
#  'tafia',
#  'ectethmoid',
#  'patronizingly',
#  'invaginable',
#  'ghostweed',
#  'teameo',
#  'uncholeric',
#  'caulerpaceous',
#  'egged',
#  'courtman',
#  'nutate',
#  'touchmark',
#  'zealousy',
#  'haj',
#  'otographical',
#  'nonpreventively',
#  'plaintiffs',
#  'rps',
#  'crewelwork',
#  'sheerer',
#  'authorise',
#  'heterochromous',
#  "cookie's",
#  'pseudohydrophobia',
#  'nonrescissory',
#  'soupling',
#  'secularness',
#  'admonitions',
#  'drips',
#  'protagonism',
#  'pacota',
#  'baedekers',
#  'philobiblical',
#  'rockabyes',
#  'heritress',
#  'subdititious',
#  'nontoned',
#  'saltatorial',
#  'blepharitic',
#  'appurtenant',
#  'cowered',
#  'holdovers',
#  'nonblasphemies',
#  'swilltub',
#  'ulama',
#  'defial',
#  'participable',
#  'unsurety',
#  'uppour',
#  'osteoencephaloma',
#  'infangthief',
#  'reciprocantive',
#  'unconnectedly',
#  'arcsin',
#  'kisser',
#  'polyoicous',
#  'pharmacodiagnosis',
#  'tunder',
#  'stoloniferous',
#  'troopial',
#  'grocer',
#  'microspectrophotometric',
#  'inferible',
#  'thready',
#  'anthropodeoxycholic',
#  'overthrow',
#  'paruria',
#  'meadowlarks',
#  'affrighting',
#  'lecithic',
#  'vases',
#  'antiministerial',
#  'activated',
#  'presidencies',
#  'florigens',
#  'septennate',
#  'snively',
#  'pinfeathered',
#  'bloodguilt',
#  'waterwall',
#  'ethanolamine',
#  'kamerad',
#  'tetchily',
#  'gatherings',
#  'uncompaniable',
#  'airth',
#  'irreverend',
#  'presupposal',
#  'nonconfined',
#  'sises',
#  'kilerg',
#  'forgeability',
#  'gamobium',
#  'rodders',
#  'schlieren',
#  'listener',
#  'joist',
#  'oscitancies',
#  'coarrange',
#  'ecologists',
#  'hoactzines',
#  'icteruses',
#  'glazily',
#  'podiatries',
#  'czardas',
#  'nautili',
#  'chololithic',
#  'multisyllability',
#  'wobbled',
#  'remotive',
#  'acrawl',
#  'unmighty',
#  'shrimpers',
#  'bootable',
#  'glimmering',
#  'jugginses',
#  'cacothesis',
#  'restyled',
#  'variolite',
#  "mate's",
#  'sulcar',
#  'bogwort',
#  'agglutinize',
#  'synanthetic',
#  'transradiable',
#  'moyenant',
#  'submarines',
#  'planter',
#  'piezochemistry',
#  'protodonate',
#  'psocine',
#  'primordial',
#  'proofing',
#  'sill',
#  'garnishees',
#  'squillgeed',
#  'protariff',
#  'interlobar',
#  'organule',
#  'consecrated',
#  'peerhood',
#  'execs',
#  'dotards',
#  'carabao',
#  'contestation',
#  'agric',
#  'intracistern',
#  'winebibbery',
#  'alumniate',
#  'yattered',
#  'pleurodiran',
#  'sufferer',
#  'bye',
#  'propitiating',
#  'unfooled',
#  'deedier',
#  'nixie',
#  'macrotherioid',
#  'amblingly',
#  'nuggets',
#  'profligate',
#  'nontaxably',
#  'bishopess',
#  'scabrous',
#  'err',
#  'atlantes',
#  'dominique',
#  'hyperpathetical',
#  'blameworthy',
#  'malingering',
#  'abstrusities',
#  'whitecap',
#  'wolfian',
#  'ternery',
#  'peltinerved',
#  'cons',
#  "lobster's",
#  'perifollicular',
#  'hawsers',
#  'breathable',
#  'postsign',
#  'berouged',
#  'endodontic',
#  'anatira',
#  'retinning',
#  'gardenia',
#  'unescutcheoned',
#  'crases',
#  'metreless',
#  'warped',
#  'snapshot',
#  'subradiancy',
#  "technicality's",
#  'venerian',
#  'incaptivate',
#  'decretal',
#  'familiarisingly',
#  'ghillie',
#  'woolder',
#  'bushhammer',
#  'grandfatherly',
#  'pulleys',
#  'integrant',
#  "benchmark's",
#  'dispenser',
#  'documentation',
#  'transporters',
#  'operceles',
#  'guff',
#  'spatterproof',
#  'handouts',
#  'canoodler',
#  'hetaery',
#  'folkmote',
#  'healthfully',
#  'lipoids',
#  'watermelons',
#  'morphic',
#  'unsonsie',
#  'intuent',
#  'relativistic',
#  'punctulum',
#  'supercalender',
#  'fourfiusher',
#  'fibrillating',
#  'louk',
#  'revulsant',
#  'volumette',
#  'emerge',
#  'dispergate',
#  'clistothcia',
#  'reciprocates',
#  'maxixes',
#  'upraught',
#  'fowl',
#  'gonapophysal',
#  'typhlostenosis',
#  'breasted',
#  'akenbold',
#  'hydromaniac',
#  'haya',
#  'fullering',
#  'dactyliomancy',
#  'undelved',
#  'nighs',
#  'walling',
#  'buckskinned',
#  'natured',
#  'osteologer',
#  'malaysia',
#  'forgottenness',
#  'macrolecithal',
#  'carrick',
#  'subimbricative',
#  'desirefulness',
#  'retentivity',
#  'antioxygenating',
#  'undaunting',
#  'staggart',
#  'scribatiousness',
#  'unlaying',
#  'agnomina',
#  'targes',
#  'circumsail',
#  'tautonymic',
#  'dent',
#  'stoppability',
#  'euflavine',
#  'luxuriance',
#  'hetairist',
#  'playreader',
#  'steamerload',
#  'foaly',
#  'anagrammatism',
#  'bunyah',
#  'archrepresentative',
#  'subreption',
#  'jurisprude',
#  'buriels',
#  'pinacolin',
#  'seminuria',
#  'pyrylium',
#  'unpunctilious',
#  'embloom',
#  'mockingstock',
#  'uncompleteness',
#  'limnological',
#  'meadow',
#  'ampelopsis',
#  'furzechat',
#  'pekin',
#  'stational',
#  'embaphium',
#  'candlepins',
#  'ungt',
#  'retaught',
#  'ungradually',
#  'flechette',
#  'bandpass',
#  'girthed',
#  'oophorostomy',
#  'subsynodically',
#  'nonsmoker',
#  'resight',
#  'nondelicate',
#  'sporozoa',
#  'recanted',
#  'uveas',
#  'resiled',
#  'itchy',
#  'frankly',
#  'ghettoing',
#  'hawkish',
#  'teredo',
#  'atraumatic',
#  'ptinid',
#  'uncanonized',
#  'flyings',
#  'synurae',
#  'budzart',
#  'aurobromide',
#  'thorpe',
#  'queensberry',
#  'resuspend',
#  'guanylic',
#  'sepsine',
#  'myxamoeba',
#  'connaraceous',
#  'continent',
#  'resiance',
#  'fictionalizing',
#  'subadministrator',
#  'burlesks',
#  "captive's",
#  'dissensualize',
#  'horridly',
#  'untaught',
#  'shellshake',
#  "toothbrush's",
#  'pygigidia',
#  'unrefuting',
#  'citraconic',
#  'cyclo',
#  'flaxwoman',
#  'furrower',
#  "armament's",
#  'actious',
#  'dammaret',
#  'asker',
#  'soupcons',
#  'colotomies',
#  'forfear',
#  'foremelt',
#  'empacket',
#  'redeem',
#  'morale',
#  'retaliator',
#  'cyanuramide',
#  'overchafe',
#  'prerespectability',
#  'defamingly',
#  'concussation',
#  'fluidics',
#  'colonel',
#  'perceives',
#  'wheelie',
#  'countably',
#  'hydrocinnamyl',
#  'miauler',
#  'raphias',
#  'deciduously',
#  'monkfish',
#  'hosted',
#  'tannage',
#  'slud',
#  'globosphaerite',
#  'misanthropism',
#  'polydymite',
#  'crossbolt',
#  'hatbrim',
#  'induement',
#  'anaseismic',
#  'materialistically',
#  'aire',
#  'proconference',
#  'feeb',
#  'inspiritingly',
#  'acquaintanceship',
#  'schematize',
#  'unfrothed',
#  'dextrotropous',
#  'panspermist',
#  'potty',
#  'iridoplegia',
#  'insectival',
#  'pyrroporphyrin',
#  'horreum',
#  'transfused',
#  'sparagus',
#  'overreaches',
#  'archibenthos',
#  'prodelision',
#  'parling',
#  'bruang',
#  'unvulgarise',
#  'shaatnez',
#  'wordstar',
#  'domiciling',
#  'malie',
#  'ballista',
#  'hoodoes',
#  'exaltee',
#  'tongueplay',
#  'showy',
#  'euphemian',
#  'ezan',
#  'telegraphically',
#  'wisdom',
#  'inshave',
#  'teleph',
#  'countrymen',
#  'promulged',
#  'leadableness',
#  'outstrove',
#  'colonialists',
#  'hamfare',
#  'cardiasthma',
#  'gamma',
#  'hypercomplex',
#  'mouillation',
#  'postfoetal',
#  'rebuckle',
#  'preexhaustion',
#  'nobbier',
#  'sarcophagid',
#  'maeandrine',
#  'wagered',
#  'undeeded',
#  'auris',
#  'uncourageousness',
#  'wolverine',
#  'orthodoxally',
#  'zemmi',
#  'churchish',
#  'empowering',
#  'intriguess',
#  'deplaceable',
#  'curassow',
#  'undeflectable',
#  'bens',
#  'witenagemot',
#  'dalle',
#  'alanyl',
#  'overinvestment',
#  'overcontract',
#  'urticant',
#  'algerita',
#  'jako',
#  'breakpoints',
#  'cutikin',
#  'mn',
#  'roupit',
#  'deploring',
#  'hawkery',
#  'rebook',
#  'accumulator',
#  'situating',
#  'rashing',
#  'hootch',
#  'hydrostat',
#  'unbridledly',
#  'karch',
#  'omnivore',
#  'hymnic',
#  'originator',
#  'pseudonitrol',
#  'pearceite',
#  'tantalize',
#  'oneirocritical',
#  'amblygonite',
#  'egosyntonic',
#  'lubber',
#  'overindustrializing',
#  'cytochylema',
#  'tegurium',
#  'circumaviate',
#  'unnormal',
#  'selffulness',
#  'ligustrin',
#  'chancer',
#  'tenselessness',
#  'manitous',
#  'preambitiously',
#  'topoalgia',
#  'crabut',
#  'xerodermatous',
#  'jactancy',
#  'horsewomanship',
#  'hoplitodromos',
#  'protestable',
#  'teemless',
#  'corollary',
#  'sordidity',
#  'premial',
#  'adhesions',
#  'hel',
#  'agromania',
#  'platens',
#  'eagerest',
#  'subfamily',
#  'valkyries',
#  'birthless',
#  'tetrodont',
#  'colotyphoid',
#  'gingko',
#  "applicant's",
#  'pelviolithotomy',
#  'gerontotherapies',
#  'twelvescore',
#  'mercaptan',
#  'workout',
#  'unwearily',
#  'ealdorman',
#  'alkalimetric',
#  'nevo',
#  'taxable',
#  'repapering',
#  'madnep',
#  'sermoneer',
#  'sugarplum',
#  'arctician',
#  'hydrid',
#  'spermaturia',
#  'donenesses',
#  'rememberers',
#  'telethermometer',
#  'undercut',
#  'irresistibility',
#  'sitz',
#  'rebarbative',
#  'uncapsuled',
#  'subsulphid',
#  'haustoria',
#  'powderizer',
#  'professions',
#  'purgatorial',
#  'tamed',
#  'hosier',
#  'condictious',
#  'upfingered',
#  'eucaine',
#  'philosophizing',
#  'competingly',
#  'composedly',
#  'gastraead',
#  'consolette',
#  'lousiness',
#  'meritmonger',
#  'mischio',
#  'biguttulate',
#  'prefroze',
#  'orthostichy',
#  'descloizite',
#  'berth',
#  'connexure',
#  'oximetric',
#  'rollmops',
#  "apartment's",
#  'manipulability',
#  'ozones',
#  'nonassortment',
#  'smartism',
#  'gnomologic',
#  'deleterious',
#  'fluorescein',
#  'huckaback',
#  "rung's",
#  'dispand',
#  'prewarned',
#  'intercess',
#  'mesentera',
#  'stomatode',
#  'colutea',
#  'combining',
#  'adagissimo',
#  'jollification',
#  'apprecate',
#  'representor',
#  'overtimes',
#  'osteostracan',
#  'sulphurean',
#  'tapered',
#  'antependium',
#  'papability',
#  'brushball',
#  'cheeping',
#  'unusuriousness',
#  'disappointing',
#  'ugh',
#  'unlured',
#  "bartender's",
#  'zoomantic',
#  'upbuoyance',
#  'dimyarian',
#  'goyle',
#  'unverminousness',
#  'friarly',
#  'trottles',
#  'conviciate',
#  'backstaff',
#  'noncommercial',
#  'prerelate',
#  'predivide',
#  'presupposed',
#  'parishionate',
#  'splaymouth',
#  'unintentionalness',
#  'undisbursed',
#  'ridiculed',
#  'cistern',
#  'deerskins',
#  'homeomorphisms',
#  'agamas',
#  'outrigger',
#  'sweeten',
#  'parlay',
#  'diode',
#  'seropurulent',
#  'contemning',
#  'mothergate',
#  'sonar',
#  'tph',
#  'inemotivity',
#  "misrepresentation's",
#  'pedagogical',
#  'filmogen',
#  'gartering',
#  'therapeuses',
#  'itemy',
#  'exiguities',
#  'scuppaugs',
#  'hunt',
#  'rammel',
#  'exhibitant',
#  'caroluses',
#  "heretic's",
#  'inaffably',
#  'alveolariform',
#  'appressorial',
#  'cephadia',
#  'unobscure',
#  'lur',
#  'gawney',
#  'sialoangitis',
#  'vexatiousness',
#  'unmirthful',
#  'turbinelike',
#  'overinvests',
#  'peribursal',
#  'acritical',
#  'ammonals',
#  'dish',
#  'millithrum',
#  'actinopod',
#  'blamingly',
#  'rains',
#  'communicated',
#  'festae',
#  'pioneering',
#  'hexadiene',
#  'flugel',
#  'remarriage',
#  'tragedienne',
#  'verticalled',
#  'reinstill',
#  'liberty',
#  'barmote',
#  'duotriacontane',
#  'etiolin',
#  'mashman',
#  'superqualifying',
#  'tattering',
#  "valentine's",
#  'coenamors',
#  'mullas',
#  'subfuscous',
#  'typhogenic',
#  'pigmental',
#  'berdaches',
#  'collusiveness',
#  'abhiseka',
#  'untestate',
#  'starny',
#  'bolograph',
#  'nearaway',
#  'provisionment',
#  'subanal',
#  'unhot',
#  'sporophyll',
#  'acinacious',
#  'leered',
#  'megalophonous',
#  'venomosalivary',
#  'merchantability',
#  'hawthorny',
#  'upholden',
#  'bedsonias',
#  'hadder',
#  'ecarte',
#  'inappetible',
#  'coaxial',
#  'axonolipous',
#  'bahawder',
#  'molehills',
#  'miamia',
#  'akela',
#  'athletically',
#  'mease',
#  'phonologists',
#  'expatiate',
#  'bolographic',
#  'chumps',
#  'furanoses',
#  'coho',
#  'preplacental',
#  'pyrenematous',
#  'grievously',
#  'cannisters',
#  'wispier',
#  'cupcake',
#  'antipyryl',
#  'sewin',
#  'overurges',
#  'union',
#  'incrustator',
#  'fiant',
#  'nonadaptability',
#  'cindered',
#  'bibbler',
#  'elytrocele',
#  'acromyotonus',
#  'farth',
#  'eclipsation',
#  'ignotus',
#  'preengaging',
#  'dishpans',
#  'superfamilies',
#  'severing',
#  'balsa',
#  'proterve',
#  'myelocele',
#  'caddis',
#  'wrongfile',
#  'spanaemic',
#  'palaeobiology',
#  'laparotomize',
#  "stencil's",
#  'supercommentary',
#  'decentralizations',
#  'enunciative',
#  'codescendant',
#  'beghard',
#  'vasculiform',
#  'overdefiantly',
#  'hennaed',
#  'soilure',
#  'unavenging',
#  'waddying',
#  'miffier',
#  'uncuticulate',
#  'antisialagogue',
#  'hypothecates',
#  'vesicular',
#  'trunnions',
#  'unbadgered',
#  'sq',
#  'linchet',
#  'absinthol',
#  'pyrologies',
#  'cointensity',
#  'trawl',
#  'grievant',
#  'nycturia',
#  'pileworm',
#  'seventh',
#  'unrepleness',
#  'boob',
#  'thermion',
#  'trigrammic',
#  'nonthermoplastic',
#  'potwalloper',
#  'dikage',
#  'roarer',
#  'malediction',
#  'uroedema',
#  'blushing',
#  'sublanguages',
#  'aahed',
#  'bascules',
#  'daze',
#  'changeovers',
#  'meristogenous',
#  'siliciophite',
#  'receive',
#  'foxbane',
#  'unacquaint',
#  'forche',
#  'rebrew',
#  'catabolized',
#  'pumps',
#  'tackless',
#  'terai',
#  'symmelia',
#  'ameliorated',
#  'tempters',
#  'unshoved',
#  'epizoisms',
#  'osmols',
#  'lucubrates',
#  'blason',
#  'subproctorship',
#  'electricalize',
#  'chikara',
#  'nonpalliation',
#  'slouch',
#  'smutchy',
#  'hypostasizing',
#  'crankcase',
#  'aspergillin',
#  'undersupplies',
#  'unmummied',
#  'pseudomedieval',
#  'jaggar',
#  'mystagogical',
#  'kataplectic',
#  'rouche',
#  'nebulite',
#  'pantachromatic',
#  'osteochondrous',
#  'precollude',
#  'cacoplasia',
#  'loppier',
#  'phytometric',
#  'synomosy',
#  'outgiving',
#  'paughty',
#  'branchless',
#  'spermatogonial',
#  'pseudointellectual',
#  'roughhews',
#  'premusical',
#  'marasmuses',
#  'covisitor',
#  'overproducing',
#  'twiggen',
#  'ballistocardiogram',
#  'quadrumvirate',
#  'prefragrance',
#  'abrine',
#  'nonelimination',
#  'engineless',
#  'winery',
#  'simplifiedly',
#  'whippertail',
#  'stereoisomeride',
#  'benzalazine',
#  'hypernik',
#  'cubistically',
#  'elderwoman',
#  'antioptimistical',
#  'gruppetto',
#  'milkshed',
#  'manuals',
#  'carucarius',
#  'wekau',
#  'fomes',
#  'condign',
#  'aerobacteriology',
#  'ethiopians',
#  'impresas',
#  'dialkylic',
#  ...]

# %%
wordunique.sort()

# %%
wordunique[:10]
# Out:
# ['', 'a', 'aa', 'aaa', 'aah', 'aahed', 'aahing', 'aahs', 'aal', 'aalii']

# %%
del wordunique[0]

# %%
wordunique[:10]
# Out:
# ['a', 'aa', 'aaa', 'aah', 'aahed', 'aahing', 'aahs', 'aal', 'aalii', 'aaliis']

# %%
wordclean = [word.strip().lower() for word in open('words', 'r')]

# %%
wordclean[:10]
# Out:
# ['a', 'a', 'aa', 'aaa', 'aah', 'aahed', 'aahing', 'aahs', 'aal', 'aalii']

# %%
wordclean = sorted(list(set([word.strip().lower() for word in open('words', 'r')])))
del wordclean[0]

# %%
wordclean[:10]
# Out:
# ['a', 'aa', 'aaa', 'aah', 'aahed', 'aahing', 'aahs', 'aal', 'aalii', 'aaliis']

# %% [markdown]
# ### Start Anagram

# %%
sorted('lives')
# Out:
# ['e', 'i', 'l', 's', 'v']

# %%
sorted('lives') = sorted('ei')
